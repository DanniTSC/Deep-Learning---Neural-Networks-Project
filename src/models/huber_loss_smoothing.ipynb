# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

FEATURE_COLS = [
    "daily_return", "log_return_1d", "return_5d", "return_20d",
    "intraday_range", "open_close_return", "volume_change_1d",
    "volume_ratio_20d", "ma_5_ratio", "ma_20_ratio", "ma_60_ratio",
    "volatility_5d", "volatility_10d", "volatility_20d", "volatility_60d",
    "past_max_drawdown_10d", "past_max_drawdown_20d", "past_max_drawdown_60d",
]
TARGET_COL = "future_max_drawdown_10d"

df = pd.read_csv(
    "/kaggle/input/datasets/bogdantrascau/proiect-dnn/features_targets_nasdaq.csv",
    parse_dates=['Date'],
    date_format='%Y-%m-%d'
)
df = df.drop(columns=["Open", "High", "Low", "Close", "Volume"], errors="ignore")

print(df.info())
print(df.head())
# Out:
# 2026-06-13 18:46:17.115481: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781376377.337234      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781376377.397317      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781376377.901028      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781376377.901065      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781376377.901067      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781376377.901070      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212433 entries, 0 to 212432
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Symbol                   212433 non-null  object
#  1   Date                     212433 non-null  datetime64[ns]
#  2   daily_return             212433 non-null  float64
#  3   log_return_1d            212433 non-null  float64
#  4   return_5d                212433 non-null  float64
#  5   return_10d               212433 non-null  float64
#  6   return_20d               212433 non-null  float64
#  7   intraday_range           212433 non-null  float64
#  8   open_close_return        212433 non-null  float64
#  9   volume_change_1d         212433 non-null  float64
#  10  volume_ratio_20d         212433 non-null  float64
#  11  sma_5                    212433 non-null  float64
#  12  sma_10                   212433 non-null  float64
#  13  sma_20                   212433 non-null  float64
#  14  sma_60                   212433 non-null  float64
#  15  ma_5_ratio               212433 non-null  float64
#  16  ma_20_ratio              212433 non-null  float64
#  17  ma_60_ratio              212433 non-null  float64
#  18  volatility_5d            212433 non-null  float64
#  19  volatility_10d           212433 non-null  float64
#  20  volatility_20d           212433 non-null  float64
#  21  volatility_60d           212433 non-null  float64
#  22  past_max_drawdown_10d    212433 non-null  float64
#  23  past_max_drawdown_20d    212433 non-null  float64
#  24  past_max_drawdown_60d    212433 non-null  float64
#  25  return_lag_1             212433 non-null  float64
#  26  return_lag_2             212433 non-null  float64
#  27  return_lag_3             212433 non-null  float64
#  28  return_lag_5             212433 non-null  float64
#  29  future_max_drawdown_10d  212433 non-null  float64
# dtypes: datetime64[ns](1), float64(28), object(1)
# memory usage: 48.6+ MB
# None
#   Symbol       Date  daily_return  log_return_1d  return_5d  return_10d  \
# 0   AAPL 2001-03-26     -0.053080      -0.054541   0.059096    0.169272
# 1   AAPL 2001-03-27      0.050141       0.048925   0.161547    0.169196
# 2   AAPL 2001-03-28     -0.030607      -0.031085   0.101558    0.084658
# 3   AAPL 2001-03-29      0.016166       0.016036   0.041688    0.144198
# 4   AAPL 2001-03-30     -0.020383      -0.020593  -0.040419    0.124394
#
#    return_20d  intraday_range  open_close_return  volume_change_1d  ...  \
# 0    0.116887        0.113317          -0.058354         -0.222704  ...
# 1    0.180347        0.052323           0.042369         -0.259574  ...
# 2    0.214790        0.045397           0.004058          0.076940  ...
# 3    0.201613        0.089763           0.034722          0.047176  ...
# 4    0.146306        0.061088          -0.021356         -0.346856  ...
#
#    volatility_20d  volatility_60d  past_max_drawdown_10d  \
# 0        0.046482        0.044373                0.05308
# 1        0.047364        0.044703                0.05308
# 2        0.045671        0.043281                0.05308
# 3        0.045527        0.043043                0.05308
# 4        0.045841        0.042758                0.05308
#
#    past_max_drawdown_20d  past_max_drawdown_60d  return_lag_1  return_lag_2  \
# 0               0.133629               0.160917      0.063439      0.074569
# 1               0.133629               0.160917     -0.053080      0.063439
# 2               0.133629               0.160917      0.050141     -0.053080
# 3               0.133629               0.160917     -0.030607      0.050141
# 4               0.133629               0.160917      0.016166     -0.030607
#
#    return_lag_3  return_lag_5  future_max_drawdown_10d
# 0      0.022184      0.047646                 0.104654
# 1      0.074569     -0.042484                 0.147405
# 2      0.063439      0.022184                 0.120485
# 3     -0.053080      0.074569                 0.134477
# 4      0.050141      0.063439                 0.116468
#
# [5 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(20, 16))

corr_matrix = df[FEATURE_COLS + [TARGET_COL]].corr()

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    annot_kws={"size": 8},
    linewidths=0.5,
    linecolor="white",
    square=True,
    ax=ax,
    vmin = -1,
    vmax = 1
)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=10)

plt.title("Feature Correlation Matrix", fontsize=14, pad=12)
plt.tight_layout()
plt.show()

# %%
# I. Estimarea dropdown ului pentru o singura companie pe baza regresiei sinusoidale

from scipy.optimize import curve_fit

class CurveEstimator():

    def __init__(self,trend,numberOfEstimators,numberOfOscilations,oscFunctions):
        self.__trend = trend
        self.__nOfEstimators = numberOfEstimators
        self.__nOfOscilations = numberOfOscilations
        self.__oscFunctions = oscFunctions
        self.params = []

    # A f p T
    def __fnTemplate(self,t,*params):
        osc = 0
        trend = 0

        if self.__nOfEstimators > 0:
            trend = self.__trend(t,*params[0:self.__nOfEstimators])
            
        it = 0
        for i in range(self.__nOfEstimators,len(params),3):
            osc += params[i] *self. __oscFunctions[it](params[i+1]*t  + params[i+2])
            it += 1
        
        return trend+osc

    def fit(self,t,y):
        
        estimators = [0.0 for i in range(self.__nOfEstimators-1)]
        estimators.append(np.mean(y))
        oscilations = []
        
        for i in range(self.__nOfOscilations):
            oscilations.append((np.max(y) - np.min(y)) / 4)
            oscilations.append(1.0)
            oscilations.append(0.0)
            
 
        params, _ = curve_fit(self.__fnTemplate,t, y, p0=estimators+oscilations)
        self.params = params
        
    def plot(self,t,df:pd.DataFrame):
        df_temp = df.copy()
        df_temp['pred'] = self.__fnTemplate(t, *self.params)
        df_temp.plot()
        
    def predict(self,t):
        return self.__fnTemplate(t, *self.params)

# %%
random_company = df['Symbol'].sample(1).values[0]
df_curve = df[df['Symbol'] == random_company].copy()
df_curve.set_index('Date', inplace=True)
df_curve = df_curve[[TARGET_COL]]
df_curve = df_curve[df_curve.index.year >= 2024]
days = (df_curve.index - df_curve.index[0]).days.values

# %%
import itertools

def trend(t, a, b, c, d, e):
    return a*t**4 + b*t**3 + c*t**2 + d*t + e
    
trend_configs = [
    (trend, 5, 1, [np.sin]),
    (trend, 5, 2, [np.sin, np.sin]),
    (trend, 5, 2, [np.sin, np.cos]),
    (trend, 5, 3, [np.sin, np.cos, np.sin]),
    (trend, 5, 3, [np.sin, np.sin, np.sin]),
]

flat_trend = lambda t, a: a

flat_configs = [
    (flat_trend, 1, 1, [np.sin]),
    (flat_trend, 1, 2, [np.sin, np.cos]),
    (flat_trend, 1, 3, [np.sin, np.sin, np.sin]),
]

all_configs = trend_configs + flat_configs

n_cols = 2
n_rows = (len(all_configs) + 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 4))
axes = axes.flatten()

df_fit = df_curve.iloc[:-30]
df_pred = df_curve.iloc[-30:]

days_fit = (df_fit.index - df_fit.index[0]).days.values
days_pred = (df_pred.index - df_fit.index[0]).days.values

for i, (trend_fn, n_est, n_osc, osc_fns) in enumerate(all_configs):
    try:
        estimator = CurveEstimator(trend_fn, n_est, n_osc, osc_fns)
        estimator.fit(days_fit, df_fit[TARGET_COL].values)

        df_temp = df_pred.copy()
        df_temp['pred'] = estimator.predict(days_pred)
        df_temp.plot(ax=axes[i])

        osc_names = [f.__name__ for f in osc_fns]
        axes[i].set_title(f"n_est={n_est}, osc={osc_names}")
    except Exception as e:
        axes[i].set_title(f"Config {i} failed: {e}")
                          
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# I. Estimarea dropdown ului pentru o singura companie pe baza SARIMA + NETEZIRE

random_company = df['Symbol'].sample(1).values[0]
df_smooth = df[df['Symbol'] == random_company].copy()
df_smooth.set_index('Date', inplace=True)
df_smooth = df_smooth[[TARGET_COL]]
df_smooth = df_smooth[df_smooth.index.year >= 2020]
df_smooth.plot(title='Original Series')
plt.show()

# %%
window_size = 6
df_smooth['SMA'] = df_smooth[TARGET_COL].rolling(window=window_size).mean()

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df_smooth[df_smooth.index.year >= 2025][TARGET_COL], label='Original Data', color='blue')
plt.plot(df_smooth[df_smooth.index.year >= 2025]['SMA'], label=f'SMA (window={window_size})', color='red')
plt.title('Simple Moving Average Smoothing')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

df_smooth = df_smooth.drop(columns=[TARGET_COL]).dropna()

# %%
# !pip install arch
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from arch.unitroot import PhillipsPerron, ADF
from statsmodels.tsa.stattools import kpss
import statsmodels.api as sm
from scipy import stats
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import root_mean_squared_error,r2_score
import math
from statsmodels.tsa.seasonal import STL
from scipy.stats import boxcox
from statsmodels.tsa.deterministic import Fourier
# Out:
# Collecting arch
#   Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from arch) (2.4.6)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from arch) (2.3.3)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from arch) (0.14.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2026.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->arch) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->arch) (1.17.0)
# Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (981 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 15.6 MB/s eta 0:00:00 0:00:01
# Installing collected packages: arch
# Successfully installed arch-8.0.0

# %%
# Seasonal decomposition (additive)
additive_decomposition = seasonal_decompose(df_smooth, model='additive', period=30)
additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

print(additive_decomposition.trend)


pp_test = PhillipsPerron(df_smooth)
print(pp_test.summary())

kpss_stat, p_value, lags, crit = kpss(df_smooth, regression='c', nlags='auto')
print(f"KPSS Statistic: {kpss_stat}")
print(f"p-value: {p_value}")
print(f"Critical Values: {crit}")

adf = ADF(df_smooth)
print(adf.summary().as_text())

n_lags = min(len(df_smooth) // 4, 40)

plot_acf(df_smooth['SMA'], lags=n_lags)
plt.title("ACF before differencing")
plt.show()

plot_pacf(df_smooth['SMA'], lags=n_lags, method='ywm')
plt.title("PACF before differencing")
plt.show()

df_orig = df_smooth.copy()
df_smooth = df_smooth.diff(12).dropna()
df_smooth.plot()
plt.show()
# Out:
# Date
# 2020-01-09   NaN
# 2020-01-10   NaN
# 2020-01-13   NaN
# 2020-01-14   NaN
# 2020-01-15   NaN
#               ..
# 2026-04-07   NaN
# 2026-04-08   NaN
# 2026-04-09   NaN
# 2026-04-10   NaN
# 2026-04-13   NaN
# Name: trend, Length: 1544, dtype: float64
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -5.720
# P-value                         0.000
# Lags                               24
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.43 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# KPSS Statistic: 0.13055417885942894
# p-value: 0.1
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -5.001
# P-value                         0.000
# Lags                               24
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.43 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# /tmp/ipykernel_58/442734623.py:13: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat, p_value, lags, crit = kpss(df_smooth, regression='c', nlags='auto')

# %%
# !pip install pmdarima
from pmdarima import auto_arima

df_fit = df_smooth.iloc[:-30]
df_pred = df_smooth.iloc[-30:]

model = auto_arima(
    df_fit['SMA'],
    d=0,
    seasonal=True,
    m=5,
    information_criterion='aic',
    stepwise=True,
    trace=True
)

forecast = model.predict(n_periods=30)

plt.figure(figsize=(14, 5))
plt.plot(df_pred.index, df_pred['SMA'], label='Actual', color='green')
plt.plot(df_pred.index, forecast, label='Forecast', color='red', linestyle='--')
plt.title('ARIMA Forecast vs Actual (last 2 months')
plt.legend()
plt.show()
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.4.6)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.3.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2026.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 10.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[5] intercept   : AIC=-11692.759, Time=2.79 sec
#  ARIMA(0,0,0)(0,0,0)[5] intercept   : AIC=-5786.029, Time=0.17 sec
#  ARIMA(1,0,0)(1,0,0)[5] intercept   : AIC=-9967.179, Time=0.68 sec
#  ARIMA(0,0,1)(0,0,1)[5] intercept   : AIC=inf, Time=2.64 sec
#  ARIMA(0,0,0)(0,0,0)[5]             : AIC=-5787.984, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,1)[5] intercept   : AIC=-11692.010, Time=0.95 sec
#  ARIMA(2,0,2)(1,0,0)[5] intercept   : AIC=-11696.014, Time=2.95 sec
#  ARIMA(2,0,2)(0,0,0)[5] intercept   : AIC=-11694.010, Time=1.20 sec
#  ARIMA(2,0,2)(2,0,0)[5] intercept   : AIC=-11690.117, Time=4.23 sec
#  ARIMA(2,0,2)(2,0,1)[5] intercept   : AIC=-11694.288, Time=4.69 sec
#  ARIMA(1,0,2)(1,0,0)[5] intercept   : AIC=-11268.766, Time=2.84 sec
#  ARIMA(2,0,1)(1,0,0)[5] intercept   : AIC=-11681.210, Time=1.92 sec
#  ARIMA(3,0,2)(1,0,0)[5] intercept   : AIC=-11693.223, Time=2.20 sec
#  ARIMA(2,0,3)(1,0,0)[5] intercept   : AIC=-11695.843, Time=2.94 sec
#  ARIMA(1,0,1)(1,0,0)[5] intercept   : AIC=-10778.687, Time=1.25 sec
#  ARIMA(1,0,3)(1,0,0)[5] intercept   : AIC=-11324.495, Time=2.04 sec
#  ARIMA(3,0,1)(1,0,0)[5] intercept   : AIC=-11667.148, Time=1.63 sec
#  ARIMA(3,0,3)(1,0,0)[5] intercept   : AIC=-11391.614, Time=4.78 sec
#  ARIMA(2,0,2)(1,0,0)[5]             : AIC=-11697.914, Time=1.16 sec
#  ARIMA(2,0,2)(0,0,0)[5]             : AIC=-11696.003, Time=0.35 sec
#  ARIMA(2,0,2)(2,0,0)[5]             : AIC=-11695.709, Time=3.38 sec
#  ARIMA(2,0,2)(1,0,1)[5]             : AIC=-11694.756, Time=1.63 sec
#  ARIMA(2,0,2)(0,0,1)[5]             : AIC=-11694.003, Time=0.72 sec
#  ARIMA(2,0,2)(2,0,1)[5]             : AIC=-11691.641, Time=2.97 sec
#  ARIMA(1,0,2)(1,0,0)[5]             : AIC=-11277.370, Time=1.30 sec
#  ARIMA(2,0,1)(1,0,0)[5]             : AIC=-11668.231, Time=1.24 sec
#  ARIMA(3,0,2)(1,0,0)[5]             : AIC=-11695.223, Time=1.58 sec
#  ARIMA(2,0,3)(1,0,0)[5]             : AIC=-11697.648, Time=1.50 sec
#  ARIMA(1,0,1)(1,0,0)[5]             : AIC=-10780.688, Time=0.91 sec
#  ARIMA(1,0,3)(1,0,0)[5]             : AIC=-11323.282, Time=1.78 sec
#  ARIMA(3,0,1)(1,0,0)[5]             : AIC=-11691.363, Time=1.89 sec
#  ARIMA(3,0,3)(1,0,0)[5]             : AIC=-11583.058, Time=3.83 sec
#
# Best model:  ARIMA(2,0,2)(1,0,0)[5]
# Total fit time: 64.271 seconds
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
#III. Analiza serii de timp multivariate pentru o singura companie
from statsmodels.tsa.stattools import adfuller, coint
from statsmodels.tsa.api import VAR
from statsmodels.tsa.vector_ar.vecm import coint_johansen, VECM

random_company = df['Symbol'].sample(1).values[0]
df_multi = df[df['Symbol'] == random_company].copy().drop(columns=['Symbol'])
df_multi = df_multi[[TARGET_COL, "Date"] + FEATURE_COLS]
df_multi.set_index('Date', inplace=True)
df_multi = df_multi[df_multi.index.year >= 2020]

df_multi.info()

# Test de cointegrare
for i in range(len(df_multi.columns)-1):
    for j in range(i+1, len(df_multi.columns)):
        col1 = df_multi.columns[i]
        col2 = df_multi.columns[j]
        if col1 != TARGET_COL and col2 != TARGET_COL:
            continue
        
        coint_t, p_value, crit_values = coint(df_multi[col1], df_multi[col2])
        print(f"{col1} si {col2}")
        print("\nCointegration Test Result:")
        print(f"T-statistic: {coint_t}")
        print(f"P-value: {p_value}")
        print(f"Critical Values: {crit_values}")
        if p_value < 0.05:
            print("✅ The series are cointegrated.")
        else:
            print("❌ The series are NOT cointegrated.")

for it in df_multi.columns:
    chk = adfuller(df_multi[it],autolag='AIC')
    if chk[1] < 0.05:
        print(f"{it} e stationara")
    else:
        print(f"{it} e nestationara")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1549 entries, 2020-01-01 to 2026-04-13
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   future_max_drawdown_10d  1549 non-null   float64
#  1   daily_return             1549 non-null   float64
#  2   log_return_1d            1549 non-null   float64
#  3   return_5d                1549 non-null   float64
#  4   return_20d               1549 non-null   float64
#  5   intraday_range           1549 non-null   float64
#  6   open_close_return        1549 non-null   float64
#  7   volume_change_1d         1549 non-null   float64
#  8   volume_ratio_20d         1549 non-null   float64
#  9   ma_5_ratio               1549 non-null   float64
#  10  ma_20_ratio              1549 non-null   float64
#  11  ma_60_ratio              1549 non-null   float64
#  12  volatility_5d            1549 non-null   float64
#  13  volatility_10d           1549 non-null   float64
#  14  volatility_20d           1549 non-null   float64
#  15  volatility_60d           1549 non-null   float64
#  16  past_max_drawdown_10d    1549 non-null   float64
#  17  past_max_drawdown_20d    1549 non-null   float64
#  18  past_max_drawdown_60d    1549 non-null   float64
# dtypes: float64(19)
# memory usage: 242.0 KB
# future_max_drawdown_10d si daily_return
#
# Cointegration Test Result:
# T-statistic: -8.063070079315736
# P-value: 2.0975278732104602e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si log_return_1d
#
# Cointegration Test Result:
# T-statistic: -8.059749852914683
# P-value: 2.1382718828725792e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si return_5d
#
# Cointegration Test Result:
# T-statistic: -8.016523883914239
# P-value: 2.746349366106446e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si return_20d
#
# Cointegration Test Result:
# T-statistic: -8.49658876694338
# P-value: 1.6758846664921081e-12
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si intraday_range
#
# Cointegration Test Result:
# T-statistic: -8.55569267401518
# P-value: 1.1852746376995738e-12
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si open_close_return
#
# Cointegration Test Result:
# T-statistic: -8.091784883084983
# P-value: 1.775870708359453e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volume_change_1d
#
# Cointegration Test Result:
# T-statistic: -7.995368229651566
# P-value: 3.103806499615693e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volume_ratio_20d
#
# Cointegration Test Result:
# T-statistic: -8.018419036436432
# P-value: 2.7163996042412897e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_5_ratio
#
# Cointegration Test Result:
# T-statistic: -7.943405117918469
# P-value: 4.1903349600210776e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_20_ratio
#
# Cointegration Test Result:
# T-statistic: -8.312671274312395
# P-value: 4.9119774294217044e-12
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_60_ratio
#
# Cointegration Test Result:
# T-statistic: -8.15076817139941
# P-value: 1.260971649088357e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_5d
#
# Cointegration Test Result:
# T-statistic: -8.21881287281807
# P-value: 8.488609879350956e-12
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_10d
#
# Cointegration Test Result:
# T-statistic: -8.081944225207774
# P-value: 1.8801607127140975e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_20d
#
# Cointegration Test Result:
# T-statistic: -8.1737071903315
# P-value: 1.1035760469150981e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_60d
#
# Cointegration Test Result:
# T-statistic: -7.993319455522451
# P-value: 3.1407885650600724e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_10d
#
# Cointegration Test Result:
# T-statistic: -8.172132474327618
# P-value: 1.1137261298437471e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_20d
#
# Cointegration Test Result:
# T-statistic: -8.832427873428681
# P-value: 2.3330743239549896e-13
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_60d
#
# Cointegration Test Result:
# T-statistic: -8.091754557451523
# P-value: 1.7761830880104738e-11
# Critical Values: [-3.90352886 -3.34007994 -3.04719093]
# ✅ The series are cointegrated.
# future_max_drawdown_10d e stationara
# daily_return e stationara
# log_return_1d e stationara
# return_5d e stationara
# return_20d e stationara
# intraday_range e stationara
# open_close_return e stationara
# volume_change_1d e stationara
# volume_ratio_20d e stationara
# ma_5_ratio e stationara
# ma_20_ratio e stationara
# ma_60_ratio e stationara
# volatility_5d e stationara
# volatility_10d e stationara
# volatility_20d e stationara
# volatility_60d e stationara
# past_max_drawdown_10d e stationara
# past_max_drawdown_20d e stationara
# past_max_drawdown_60d e stationara

# %%
df_train = df_multi.iloc[:-30]
df_test = df_multi.iloc[-30:]

model = VAR(df_train)

lag_results = model.select_order(maxlags=15)
print(lag_results.summary())

best_lag = lag_results.aic
print(f"Best lag by AIC: {best_lag}")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -146.6      -146.5   2.125e-64      -146.6
# 1       -185.7      -184.3   2.352e-81      -185.2
# 2       -186.8      -184.2   7.712e-82      -185.8
# 3       -189.4     -185.5*   5.762e-83      -187.9
# 4       -190.0      -184.9   2.941e-83      -188.1
# 5       -191.0      -184.5   1.144e-83     -188.6*
# 6       -191.1      -183.4   9.857e-84      -188.3
# 7       -191.2      -182.2   9.338e-84      -187.8
# 8       -191.4      -181.1   7.628e-84      -187.6
# 9       -191.8      -180.2   5.243e-84      -187.5
# 10      -192.2      -179.3   3.559e-84      -187.4
# 11      -192.5      -178.4   2.488e-84      -187.3
# 12      -192.5      -177.2   2.543e-84      -186.8
# 13      -192.4      -175.8   2.842e-84      -186.2
# 14      -192.3      -174.4   3.189e-84      -185.7
# 15     -192.6*      -173.4  2.486e-84*      -185.4
# --------------------------------------------------
# Best lag by AIC: 15

# %%
fitted = model.fit(best_lag)

forecast_input = df_train.values[-best_lag:]
forecast = fitted.forecast(forecast_input, steps=30)
forecast_df = pd.DataFrame(forecast, index=df_test.index, columns=df_multi.columns)

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, df_test[TARGET_COL], label='Actual', color='green')
plt.plot(forecast_df.index, forecast_df[TARGET_COL], label='Forecast', color='red', linestyle='--')
plt.title(f'VAR Forecast vs Actual - {TARGET_COL}')
plt.legend()
plt.show()

# %%
# IV. Regresie cu date de tip panel
# !pip install linearmodels
from linearmodels.panel import PanelOLS

window_size = 6
df_panel = df.copy()
df_panel[TARGET_COL] = df_panel[TARGET_COL].rolling(window=window_size).mean().dropna()
df_panel = df_panel[df_panel['Date'].dt.year >= 2020]
df_panel = df_panel.set_index(['Symbol', 'Date'])
df_panel = df_panel[[TARGET_COL] + FEATURE_COLS].dropna()

df_panel = df_panel.dropna()

split_date = df_panel.index.get_level_values('Date').unique().sort_values()[-30]

df_train = df_panel[df_panel.index.get_level_values('Date') < split_date]
df_test  = df_panel[df_panel.index.get_level_values('Date') >= split_date]

features = FEATURE_COLS
exog_train = df_train[FEATURE_COLS]
endog_train = df_train[TARGET_COL]

model = PanelOLS(endog_train, exog_train, entity_effects=True)
fitted = model.fit(cov_type='robust')
print(fitted.summary)

preds = fitted.predict(df_test[features])
df_test = df_test.copy()
df_test['pred'] = preds.values
# Out:
# Collecting linearmodels
#   Downloading linearmodels-7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (2.4.6)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (0.14.6)
# Requirement already satisfied: mypy_extensions>=0.4 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (1.1.0)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.2.1 (from linearmodels)
#   Downloading formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.2.1->linearmodels)
#   Downloading interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2026.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->linearmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->linearmodels) (26.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->linearmodels) (1.17.0)
# Downloading linearmodels-7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.5 MB/s eta 0:00:0000:0100:01
# Downloading formulaic-1.2.2-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 10.2 MB/s eta 0:00:00
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: interface-meta, pyhdfe, formulaic, linearmodels
# Successfully installed formulaic-1.2.2 interface-meta-2.0.1 linearmodels-7.0 pyhdfe-0.2.0
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     future_max_drawdown_10d   R-squared:                        0.2662
# Estimator:                        PanelOLS   R-squared (Between):             -68.172
# No. Observations:                    66026   R-squared (Within):               0.2662
# Date:                     Sat, Jun 13 2026   R-squared (Overall):             -29.197
# Time:                             18:48:04   Log-likelihood                 1.122e+05
# Cov. Estimator:                     Robust
#                                              F-statistic:                      1329.3
# Entities:                               49   P-value                           0.0000
# Avg Obs:                            1347.5   Distribution:                F(18,65959)
# Min Obs:                            172.00
# Max Obs:                            1519.0   F-statistic (robust):             769.68
#                                              P-value                           0.0000
# Time periods:                         1519   Distribution:                F(18,65959)
# Avg Obs:                            43.467
# Min Obs:                            38.000
# Max Obs:                            49.000
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# daily_return              0.0206     0.0229     0.8974     0.3695     -0.0244      0.0655
# log_return_1d            -0.0706     0.0119    -5.9117     0.0000     -0.0940     -0.0472
# return_5d                -0.1219     0.0072    -16.833     0.0000     -0.1360     -0.1077
# return_20d                0.0119     0.0041     2.8858     0.0039      0.0038      0.0200
# intraday_range            0.3309     0.0168     19.651     0.0000      0.2979      0.3639
# open_close_return         0.0029     0.0157     0.1856     0.8528     -0.0278      0.0336
# volume_change_1d         -0.0024     0.0005    -4.4222     0.0000     -0.0035     -0.0013
# volume_ratio_20d          0.0035     0.0005     6.5596     0.0000      0.0024      0.0045
# ma_5_ratio               -0.3924     0.0194    -20.215     0.0000     -0.4304     -0.3543
# ma_20_ratio               0.0635     0.0091     6.9749     0.0000      0.0457      0.0814
# ma_60_ratio              -0.0193     0.0034    -5.7444     0.0000     -0.0258     -0.0127
# volatility_5d             0.2438     0.0215     11.321     0.0000      0.2016      0.2861
# volatility_10d           -0.2061     0.0331    -6.2349     0.0000     -0.2709     -0.1413
# volatility_20d            0.0345     0.0303     1.1389     0.2548     -0.0249      0.0940
# volatility_60d           -0.0553     0.0299    -1.8504     0.0643     -0.1139      0.0033
# past_max_drawdown_10d     0.1049     0.0105     10.003     0.0000      0.0844      0.1255
# past_max_drawdown_20d     0.0572     0.0085     6.7126     0.0000      0.0405      0.0739
# past_max_drawdown_60d    -0.0048     0.0046    -1.0477     0.2948     -0.0138      0.0042
# =========================================================================================
#
# F-test for Poolability: 22.046
# P-value: 0.0000
# Distribution: F(48,65959)
#
# Included effects: Entity

# %%
sample_company = df_test.index.get_level_values('Symbol').unique()[0]
df_sample = df_test.xs(sample_company, level='Symbol')

plt.figure(figsize=(12, 4))
plt.plot(df_sample.index, df_sample[TARGET_COL], label='Actual', color='green')
plt.plot(df_sample.index, df_sample['pred'], label='Predicted', color='red', linestyle='--')
plt.title(f'PanelOLS Forecast vs Actual - {sample_company} (last 30 days)')
plt.legend()
plt.show()

# %%
# V. Predictie folosing retele neuronale
import tensorflow as tf
from sklearn.preprocessing import StandardScaler


SEQ_LEN = 30

def make_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i, :-1])
        y.append(data[i, -1])
    return np.array(X), np.array(y)

all_X_train, all_y_train = [], []
all_X_test,  all_y_test  = [], []
test_indices = {}

scaler = StandardScaler()

for company in df_panel.index.get_level_values('Symbol').unique():
    df_company = df_panel.xs(company, level='Symbol').sort_index()
    df_company = df_company[features + [TARGET_COL]].dropna()

    if len(df_company) < SEQ_LEN + 30:
        continue

    data_scaled = scaler.fit_transform(df_company.values)

    split_idx = len(df_company) - 30
    train_data = data_scaled[:split_idx]
    test_data  = data_scaled[split_idx - SEQ_LEN:]

    X_train, y_train = make_sequences(train_data, SEQ_LEN)
    X_test,  y_test  = make_sequences(test_data,  SEQ_LEN)

    all_X_train.append(X_train)
    all_y_train.append(y_train)
    all_X_test.append(X_test)
    all_y_test.append(y_test)
    test_indices[company] = df_company.index[-30:]

X_train = np.concatenate(all_X_train, axis=0)
y_train = np.concatenate(all_y_train, axis=0)
X_test  = np.concatenate(all_X_test,  axis=0)
y_test  = np.concatenate(all_y_test,  axis=0)

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (64556, 30, 18), Test: (1470, 30, 18)

# %%
def buildLSTM(seq_len, n_features):
    model_lstm = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(seq_len, n_features)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)
    ])
    model_lstm.compile(optimizer='adam', loss=tf.keras.losses.Huber(), metrics=['mae'])
    model_lstm.summary()
    return model_lstm

def buildGRU(seq_len, n_features):
    model_gru = tf.keras.Sequential([
        tf.keras.layers.GRU(64, return_sequences=True, input_shape=(seq_len, n_features)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.GRU(32),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)
    ])
    model_gru.compile(optimizer='adam', loss=tf.keras.losses.Huber(), metrics=['mae'])
    model_gru.summary()
    return model_gru

def buildCNNGRU(seq_len, n_features, hidden_size=64, dropout=0.2):
    inputs = tf.keras.Input(shape=(seq_len, n_features))
    
    x = tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", activation="relu")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.GRU(hidden_size, return_sequences=True, dropout=dropout)(x)
    x = tf.keras.layers.GRU(hidden_size // 2, dropout=dropout)(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss=tf.keras.losses.Huber(), metrics=['mae'])
    model.summary()
    return model

def buildCNNBiGRUAttention(
    seq_len,
    n_features,
    dropout=0.3,
    learning_rate=1e-3
):
    inputs = tf.keras.Input(shape=(seq_len, n_features))

    x = tf.keras.layers.Conv1D(
        filters=128,
        kernel_size=5,
        padding="same",
        activation="relu"
    )(inputs)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Conv1D(
        filters=128,
        kernel_size=3,
        padding="same",
        activation="relu"
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Dropout(dropout)(x)

    x = tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(
            128,
            return_sequences=True,
            dropout=dropout
        )
    )(x)

    x = tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(
            64,
            return_sequences=True,
            dropout=dropout
        )
    )(x)

    attn = tf.keras.layers.MultiHeadAttention(
        num_heads=4,
        key_dim=32,
        dropout=dropout
    )(x, x)

    x = tf.keras.layers.Add()([x, attn])

    x = tf.keras.layers.LayerNormalization()(x)

    avg_pool = tf.keras.layers.GlobalAveragePooling1D()(x)
    max_pool = tf.keras.layers.GlobalMaxPooling1D()(x)

    x = tf.keras.layers.Concatenate()([avg_pool, max_pool])

    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    x = tf.keras.layers.Dense(128, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    outputs = tf.keras.layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=tf.keras.losses.Huber(),
        metrics=["mae"]
    )

    model.summary()
    return model



def train(model, X_train, y_train, save_path, epochs=50, batch_size=256, validation_split=0.1, patience=3):
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=validation_split,
        callbacks=[
            tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=patience, factor=0.5, verbose=1),
            tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=patience * 2 + 1, restore_best_weights=True, verbose=1),
            tf.keras.callbacks.ModelCheckpoint(save_path, monitor="val_loss", save_best_only=True, verbose=1),
        ]
    )
    return history


def plot(history, model, X_test, y_test, all_X_test, test_indices, scaler, features, sample_company=None):
    plt.figure(figsize=(10, 3))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('LSTM Training Loss')
    plt.legend()
    plt.show()

    if sample_company is None:
        sample_company = list(test_indices.keys())[0]
    company_idx = list(test_indices.keys()).index(sample_company)

    start = sum(len(all_X_test[i]) for i in range(company_idx))
    end   = start + len(all_X_test[company_idx])

    X_company = X_test[start:end]
    y_company = y_test[start:end]
    preds = model.predict(X_company).flatten()

    n_features = len(features) + 1
    dummy = np.zeros((len(preds), n_features))
    dummy[:, -1] = preds
    preds_unscaled = scaler.inverse_transform(dummy)[:, -1]

    dummy2 = np.zeros((len(y_company), n_features))
    dummy2[:, -1] = y_company
    actual_unscaled = scaler.inverse_transform(dummy2)[:, -1]

    plt.figure(figsize=(12, 4))
    plt.plot(test_indices[sample_company], actual_unscaled, label='Actual', color='green')
    plt.plot(test_indices[sample_company], preds_unscaled, label='Predicted', color='red', linestyle='--')
    plt.title(f'Model Forecast vs Actual - {sample_company} (last 30 days)')
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

SAVE_DIR = "/kaggle/working/saved_models"
os.makedirs(SAVE_DIR, exist_ok=True)

strategy = tf.distribute.MirroredStrategy()
print(f"GPUs in use: {strategy.num_replicas_in_sync}")
NUM_GPUS = strategy.num_replicas_in_sync

with strategy.scope():
    model_configs = {
        'LSTM':   buildLSTM(seq_len=SEQ_LEN,   n_features=X_train.shape[2]),
        'GRU':    buildGRU(seq_len=SEQ_LEN,    n_features=X_train.shape[2]),
        'CNNGRU': buildCNNGRU(seq_len=SEQ_LEN, n_features=X_train.shape[2]),
        'CNNBiGRUAttention': buildCNNBiGRUAttention(seq_len=SEQ_LEN, n_features=X_train.shape[2])
    }

histories = {}
metrics   = {}

for name, model in model_configs.items():
    print(f"\n{'='*40}\nTraining {name}\n{'='*40}")

    history = train(model, X_train, y_train, save_path = os.path.join(SAVE_DIR, f"{name}.keras"), batch_size=256 * NUM_GPUS)
    histories[name] = history

    plot(history, model, X_test, y_test, all_X_test, test_indices, scaler, features)

    preds = model.predict(X_test).flatten()
    n_feat = len(features) + 1

    dummy = np.zeros((len(preds), n_feat))
    dummy[:, -1] = preds
    preds_unscaled = scaler.inverse_transform(dummy)[:, -1]

    dummy2 = np.zeros((len(y_test), n_feat))
    dummy2[:, -1] = y_test
    actual_unscaled = scaler.inverse_transform(dummy2)[:, -1]

    metrics[name] = {
        'MSE':  mean_squared_error(actual_unscaled, preds_unscaled),
        'MAE':  mean_absolute_error(actual_unscaled, preds_unscaled),
        'RMSE': np.sqrt(mean_squared_error(actual_unscaled, preds_unscaled)),
    }

metrics_df = pd.DataFrame(metrics).T
print("\n=== Model Comparison ===")
print(metrics_df.sort_values('RMSE'))

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, metric in zip(axes, ['MSE', 'MAE', 'RMSE']):
    metrics_df[metric].plot(kind='bar', ax=ax, color=['blue', 'orange', 'green'])
    ax.set_title(metric)
    ax.set_xticklabels(metrics_df.index, rotation=0)
plt.suptitle('Model Comparison')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
for name, history in histories.items():
    plt.plot(history.history['val_loss'], label=f'{name} Val Loss')
plt.title('Validation Loss Comparison')
plt.legend()
plt.show()

metrics_df.to_csv(os.path.join(SAVE_DIR, 'metrics.csv'))
print(f"Metrics saved to {SAVE_DIR}/metrics.csv")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# I0000 00:00:1781376486.361371      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1781376486.367346      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# GPUs in use: 2
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        21,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,697 (131.63 KB)
#  Trainable params: 33,697 (131.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 30, 64)         │        16,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,569 (99.88 KB)
#  Trainable params: 25,569 (99.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 30, 18)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │         3,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 30, 64)         │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,929 (206.75 KB)
#  Trainable params: 52,673 (205.75 KB)
#  Non-trainable params: 256 (1.00 KB)
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 30, 18)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 30, 128)   │     11,648 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 128)   │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 30, 128)   │     49,280 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 128)   │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 30, 128)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 30, 256)   │    198,144 │ dropout_5[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 30, 128)   │    123,648 │ bidirectional[0]… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ bidirectional_1[… │
# │ (MultiHeadAttentio… │                   │            │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 30, 128)   │          0 │ bidirectional_1[… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 30, 128)   │        256 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │     65,792 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,896 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1)         │        129 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 549,889 (2.10 MB)
#  Trainable params: 548,865 (2.09 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# ========================================
# Training LSTM
# ========================================
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# I0000 00:00:1781376492.201527     181 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1781376493.003749     182 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2931 - mae: 0.6110INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_loss improved from None to 0.27203, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.2761 - mae: 0.5862 - val_loss: 0.2720 - val_mae: 0.5911 - learning_rate: 0.0010
# Epoch 2/50
# 111/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2574 - mae: 0.5594
# Epoch 2: val_loss improved from 0.27203 to 0.26680, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2552 - mae: 0.5561 - val_loss: 0.2668 - val_mae: 0.5750 - learning_rate: 0.0010
# Epoch 3/50
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2508 - mae: 0.5484
# Epoch 3: val_loss improved from 0.26680 to 0.26327, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2440 - mae: 0.5407 - val_loss: 0.2633 - val_mae: 0.5688 - learning_rate: 0.0010
# Epoch 4/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2316 - mae: 0.5239
# Epoch 4: val_loss improved from 0.26327 to 0.26128, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2308 - mae: 0.5226 - val_loss: 0.2613 - val_mae: 0.5654 - learning_rate: 0.0010
# Epoch 5/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2214 - mae: 0.5102
# Epoch 5: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2213 - mae: 0.5095 - val_loss: 0.2678 - val_mae: 0.5792 - learning_rate: 0.0010
# Epoch 6/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2114 - mae: 0.4955
# Epoch 6: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2094 - mae: 0.4930 - val_loss: 0.2618 - val_mae: 0.5659 - learning_rate: 0.0010
# Epoch 7/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2013 - mae: 0.4819
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 7: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1991 - mae: 0.4786 - val_loss: 0.2631 - val_mae: 0.5615 - learning_rate: 0.0010
# Epoch 8/50
# 111/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1907 - mae: 0.4662
# Epoch 8: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1870 - mae: 0.4615 - val_loss: 0.2653 - val_mae: 0.5622 - learning_rate: 5.0000e-04
# Epoch 9/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1813 - mae: 0.4527
# Epoch 9: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1810 - mae: 0.4524 - val_loss: 0.2730 - val_mae: 0.5757 - learning_rate: 5.0000e-04
# Epoch 10/50
# 109/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1764 - mae: 0.4450
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 10: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1750 - mae: 0.4433 - val_loss: 0.2645 - val_mae: 0.5699 - learning_rate: 5.0000e-04
# Epoch 11/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1720 - mae: 0.4386
# Epoch 11: val_loss did not improve from 0.26128
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1694 - mae: 0.4356 - val_loss: 0.2678 - val_mae: 0.5697 - learning_rate: 2.5000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# ========================================
# Training GRU
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2875 - mae: 0.5991
# Epoch 1: val_loss improved from None to 0.27196, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2730 - mae: 0.5806 - val_loss: 0.2720 - val_mae: 0.5879 - learning_rate: 0.0010
# Epoch 2/50
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2619 - mae: 0.5666
# Epoch 2: val_loss improved from 0.27196 to 0.26981, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2618 - mae: 0.5654 - val_loss: 0.2698 - val_mae: 0.5847 - learning_rate: 0.0010
# Epoch 3/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2606 - mae: 0.5623
# Epoch 3: val_loss improved from 0.26981 to 0.26739, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2584 - mae: 0.5610 - val_loss: 0.2674 - val_mae: 0.5812 - learning_rate: 0.0010
# Epoch 4/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2560 - mae: 0.5561
# Epoch 4: val_loss improved from 0.26739 to 0.26537, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2546 - mae: 0.5556 - val_loss: 0.2654 - val_mae: 0.5769 - learning_rate: 0.0010
# Epoch 5/50
# 111/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2546 - mae: 0.5561
# Epoch 5: val_loss did not improve from 0.26537
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2505 - mae: 0.5503 - val_loss: 0.2656 - val_mae: 0.5736 - learning_rate: 0.0010
# Epoch 6/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2477 - mae: 0.5454
# Epoch 6: val_loss improved from 0.26537 to 0.26305, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 6: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2435 - mae: 0.5404 - val_loss: 0.2631 - val_mae: 0.5763 - learning_rate: 0.0010
# Epoch 7/50
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2329 - mae: 0.5259
# Epoch 7: val_loss improved from 0.26305 to 0.26202, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 7: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2341 - mae: 0.5271 - val_loss: 0.2620 - val_mae: 0.5741 - learning_rate: 0.0010
# Epoch 8/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2277 - mae: 0.5186
# Epoch 8: val_loss did not improve from 0.26202
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2261 - mae: 0.5154 - val_loss: 0.2638 - val_mae: 0.5654 - learning_rate: 0.0010
# Epoch 9/50
# 109/114 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2215 - mae: 0.5102
# Epoch 9: val_loss improved from 0.26202 to 0.25983, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 9: finished saving model to /kaggle/working/saved_models/GRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2198 - mae: 0.5065 - val_loss: 0.2598 - val_mae: 0.5658 - learning_rate: 0.0010
# Epoch 10/50
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2174 - mae: 0.5031
# Epoch 10: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2137 - mae: 0.4980 - val_loss: 0.2636 - val_mae: 0.5704 - learning_rate: 0.0010
# Epoch 11/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2082 - mae: 0.4890
# Epoch 11: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2064 - mae: 0.4875 - val_loss: 0.2669 - val_mae: 0.5668 - learning_rate: 0.0010
# Epoch 12/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1988 - mae: 0.4761
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1999 - mae: 0.4780 - val_loss: 0.2674 - val_mae: 0.5638 - learning_rate: 0.0010
# Epoch 13/50
# 111/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1887 - mae: 0.4642
# Epoch 13: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1916 - mae: 0.4663 - val_loss: 0.2687 - val_mae: 0.5638 - learning_rate: 5.0000e-04
# Epoch 14/50
# 110/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1883 - mae: 0.4601
# Epoch 14: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1867 - mae: 0.4591 - val_loss: 0.2739 - val_mae: 0.5775 - learning_rate: 5.0000e-04
# Epoch 15/50
# 109/114 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1813 - mae: 0.4526
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 15: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1830 - mae: 0.4539 - val_loss: 0.2716 - val_mae: 0.5759 - learning_rate: 5.0000e-04
# Epoch 16/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1762 - mae: 0.4452
# Epoch 16: val_loss did not improve from 0.25983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1784 - mae: 0.4472 - val_loss: 0.2648 - val_mae: 0.5613 - learning_rate: 2.5000e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# ========================================
# Training CNNGRU
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 18 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2838 - mae: 0.5962
# Epoch 1: val_loss improved from None to 0.28249, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - loss: 0.2738 - mae: 0.5820 - val_loss: 0.2825 - val_mae: 0.6135 - learning_rate: 0.0010
# Epoch 2/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2589 - mae: 0.5609
# Epoch 2: val_loss improved from 0.28249 to 0.26888, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.2529 - mae: 0.5531 - val_loss: 0.2689 - val_mae: 0.5879 - learning_rate: 0.0010
# Epoch 3/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2414 - mae: 0.5360
# Epoch 3: val_loss improved from 0.26888 to 0.25792, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.2390 - mae: 0.5344 - val_loss: 0.2579 - val_mae: 0.5734 - learning_rate: 0.0010
# Epoch 4/50
# 112/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2306 - mae: 0.5221
# Epoch 4: val_loss improved from 0.25792 to 0.25538, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2272 - mae: 0.5185 - val_loss: 0.2554 - val_mae: 0.5689 - learning_rate: 0.0010
# Epoch 5/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2171 - mae: 0.5038
# Epoch 5: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2158 - mae: 0.5023 - val_loss: 0.2854 - val_mae: 0.6021 - learning_rate: 0.0010
# Epoch 6/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2094 - mae: 0.4934
# Epoch 6: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2042 - mae: 0.4868 - val_loss: 0.2580 - val_mae: 0.5634 - learning_rate: 0.0010
# Epoch 7/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1943 - mae: 0.4718
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 7: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1933 - mae: 0.4708 - val_loss: 0.2624 - val_mae: 0.5711 - learning_rate: 0.0010
# Epoch 8/50
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1797 - mae: 0.4523
# Epoch 8: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1766 - mae: 0.4470 - val_loss: 0.2614 - val_mae: 0.5699 - learning_rate: 5.0000e-04
# Epoch 9/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1698 - mae: 0.4364
# Epoch 9: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1694 - mae: 0.4358 - val_loss: 0.2667 - val_mae: 0.5701 - learning_rate: 5.0000e-04
# Epoch 10/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1636 - mae: 0.4278
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 10: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1623 - mae: 0.4260 - val_loss: 0.2649 - val_mae: 0.5647 - learning_rate: 5.0000e-04
# Epoch 11/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1546 - mae: 0.4150
# Epoch 11: val_loss did not improve from 0.25538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1554 - mae: 0.4151 - val_loss: 0.2698 - val_mae: 0.5710 - learning_rate: 2.5000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
#
# ========================================
# Training CNNBiGRUAttention
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 38 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5673 - mae: 0.9457
# Epoch 1: val_loss improved from None to 0.33628, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - loss: 0.4528 - mae: 0.8103 - val_loss: 0.3363 - val_mae: 0.6640 - learning_rate: 0.0010
# Epoch 2/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3290 - mae: 0.6570
# Epoch 2: val_loss improved from 0.33628 to 0.30703, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.3202 - mae: 0.6444 - val_loss: 0.3070 - val_mae: 0.6130 - learning_rate: 0.0010
# Epoch 3/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2920 - mae: 0.6043
# Epoch 3: val_loss improved from 0.30703 to 0.29601, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2837 - mae: 0.5946 - val_loss: 0.2960 - val_mae: 0.5908 - learning_rate: 0.0010
# Epoch 4/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2636 - mae: 0.5677
# Epoch 4: val_loss improved from 0.29601 to 0.27145, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2612 - mae: 0.5651 - val_loss: 0.2714 - val_mae: 0.5720 - learning_rate: 0.0010
# Epoch 5/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2471 - mae: 0.5465
# Epoch 5: val_loss improved from 0.27145 to 0.26682, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 5: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2490 - mae: 0.5481 - val_loss: 0.2668 - val_mae: 0.5627 - learning_rate: 0.0010
# Epoch 6/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2398 - mae: 0.5368
# Epoch 6: val_loss did not improve from 0.26682
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 0.2405 - mae: 0.5372 - val_loss: 0.2696 - val_mae: 0.5649 - learning_rate: 0.0010
# Epoch 7/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2408 - mae: 0.5353
# Epoch 7: val_loss improved from 0.26682 to 0.25496, saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
#
# Epoch 7: finished saving model to /kaggle/working/saved_models/CNNBiGRUAttention.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.2324 - mae: 0.5259 - val_loss: 0.2550 - val_mae: 0.5591 - learning_rate: 0.0010
# Epoch 8/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2282 - mae: 0.5183
# Epoch 8: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2254 - mae: 0.5151 - val_loss: 0.2636 - val_mae: 0.5581 - learning_rate: 0.0010
# Epoch 9/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2156 - mae: 0.5031
# Epoch 9: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2182 - mae: 0.5054 - val_loss: 0.2705 - val_mae: 0.5632 - learning_rate: 0.0010
# Epoch 10/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2124 - mae: 0.4966
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.2114 - mae: 0.4958 - val_loss: 0.2651 - val_mae: 0.5694 - learning_rate: 0.0010
# Epoch 11/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2017 - mae: 0.4814
# Epoch 11: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1990 - mae: 0.4775 - val_loss: 0.2641 - val_mae: 0.5567 - learning_rate: 5.0000e-04
# Epoch 12/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1938 - mae: 0.4701
# Epoch 12: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1936 - mae: 0.4700 - val_loss: 0.2626 - val_mae: 0.5592 - learning_rate: 5.0000e-04
# Epoch 13/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1899 - mae: 0.4640
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 13: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1892 - mae: 0.4631 - val_loss: 0.2607 - val_mae: 0.5557 - learning_rate: 5.0000e-04
# Epoch 14/50
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1782 - mae: 0.4490
# Epoch 14: val_loss did not improve from 0.25496
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.1806 - mae: 0.4507 - val_loss: 0.2636 - val_mae: 0.5631 - learning_rate: 2.5000e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
#
# === Model Comparison ===
#                         MSE       MAE      RMSE
# CNNBiGRUAttention  0.004414  0.038101  0.066435
# GRU                0.004501  0.037820  0.067089
# LSTM               0.004507  0.037960  0.067133
# CNNGRU             0.004605  0.038672  0.067862
# Metrics saved to /kaggle/working/saved_models/metrics.csv

# %%
sample_companies = list(test_indices.keys())
random_companies = np.random.choice(sample_companies, size=3, replace=False)

for company in random_companies:
    plot(histories['CNNGRU'], model_configs['CNNGRU'], X_test, y_test, all_X_test, test_indices, scaler, features, sample_company=company)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
