# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

FEATURE_COLS = [
    "daily_return", "log_return_1d", "return_5d", "return_20d",
    "intraday_range", "open_close_return", "volume_change_1d",
    "volume_ratio_20d", "ma_5_ratio", "ma_20_ratio", "ma_60_ratio",
    "volatility_5d", "volatility_10d", "volatility_20d", "volatility_60d",
    "past_max_drawdown_10d", "past_max_drawdown_20d", "past_max_drawdown_60d",
]
TARGET_COL = "future_max_drawdown_10d"

df = pd.read_csv(
    "/kaggle/input/datasets/bogdantrascau/proiect-dnn/features_targets_nasdaq.csv",
    parse_dates=['Date'],
    date_format='%Y-%m-%d'
)
df = df.drop(columns=["Open", "High", "Low", "Close", "Volume"], errors="ignore")

print(df.info())
print(df.head())
# Out:
# 2026-06-13 15:08:54.767422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781363334.983841      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781363335.045992      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781363335.543965      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781363335.544008      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781363335.544011      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781363335.544013      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212433 entries, 0 to 212432
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Symbol                   212433 non-null  object
#  1   Date                     212433 non-null  datetime64[ns]
#  2   daily_return             212433 non-null  float64
#  3   log_return_1d            212433 non-null  float64
#  4   return_5d                212433 non-null  float64
#  5   return_10d               212433 non-null  float64
#  6   return_20d               212433 non-null  float64
#  7   intraday_range           212433 non-null  float64
#  8   open_close_return        212433 non-null  float64
#  9   volume_change_1d         212433 non-null  float64
#  10  volume_ratio_20d         212433 non-null  float64
#  11  sma_5                    212433 non-null  float64
#  12  sma_10                   212433 non-null  float64
#  13  sma_20                   212433 non-null  float64
#  14  sma_60                   212433 non-null  float64
#  15  ma_5_ratio               212433 non-null  float64
#  16  ma_20_ratio              212433 non-null  float64
#  17  ma_60_ratio              212433 non-null  float64
#  18  volatility_5d            212433 non-null  float64
#  19  volatility_10d           212433 non-null  float64
#  20  volatility_20d           212433 non-null  float64
#  21  volatility_60d           212433 non-null  float64
#  22  past_max_drawdown_10d    212433 non-null  float64
#  23  past_max_drawdown_20d    212433 non-null  float64
#  24  past_max_drawdown_60d    212433 non-null  float64
#  25  return_lag_1             212433 non-null  float64
#  26  return_lag_2             212433 non-null  float64
#  27  return_lag_3             212433 non-null  float64
#  28  return_lag_5             212433 non-null  float64
#  29  future_max_drawdown_10d  212433 non-null  float64
# dtypes: datetime64[ns](1), float64(28), object(1)
# memory usage: 48.6+ MB
# None
#   Symbol       Date  daily_return  log_return_1d  return_5d  return_10d  \
# 0   AAPL 2001-03-26     -0.053080      -0.054541   0.059096    0.169272
# 1   AAPL 2001-03-27      0.050141       0.048925   0.161547    0.169196
# 2   AAPL 2001-03-28     -0.030607      -0.031085   0.101558    0.084658
# 3   AAPL 2001-03-29      0.016166       0.016036   0.041688    0.144198
# 4   AAPL 2001-03-30     -0.020383      -0.020593  -0.040419    0.124394
#
#    return_20d  intraday_range  open_close_return  volume_change_1d  ...  \
# 0    0.116887        0.113317          -0.058354         -0.222704  ...
# 1    0.180347        0.052323           0.042369         -0.259574  ...
# 2    0.214790        0.045397           0.004058          0.076940  ...
# 3    0.201613        0.089763           0.034722          0.047176  ...
# 4    0.146306        0.061088          -0.021356         -0.346856  ...
#
#    volatility_20d  volatility_60d  past_max_drawdown_10d  \
# 0        0.046482        0.044373                0.05308
# 1        0.047364        0.044703                0.05308
# 2        0.045671        0.043281                0.05308
# 3        0.045527        0.043043                0.05308
# 4        0.045841        0.042758                0.05308
#
#    past_max_drawdown_20d  past_max_drawdown_60d  return_lag_1  return_lag_2  \
# 0               0.133629               0.160917      0.063439      0.074569
# 1               0.133629               0.160917     -0.053080      0.063439
# 2               0.133629               0.160917      0.050141     -0.053080
# 3               0.133629               0.160917     -0.030607      0.050141
# 4               0.133629               0.160917      0.016166     -0.030607
#
#    return_lag_3  return_lag_5  future_max_drawdown_10d
# 0      0.022184      0.047646                 0.104654
# 1      0.074569     -0.042484                 0.147405
# 2      0.063439      0.022184                 0.120485
# 3     -0.053080      0.074569                 0.134477
# 4      0.050141      0.063439                 0.116468
#
# [5 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(20, 16))

corr_matrix = df[FEATURE_COLS + [TARGET_COL]].corr()

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    annot_kws={"size": 8},
    linewidths=0.5,
    linecolor="white",
    square=True,
    ax=ax,
    vmin = -1,
    vmax = 1
)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=10)

plt.title("Feature Correlation Matrix", fontsize=14, pad=12)
plt.tight_layout()
plt.show()

# %%
# I. Estimarea dropdown ului pentru o singura companie pe baza regresiei sinusoidale

from scipy.optimize import curve_fit

class CurveEstimator():

    def __init__(self,trend,numberOfEstimators,numberOfOscilations,oscFunctions):
        self.__trend = trend
        self.__nOfEstimators = numberOfEstimators
        self.__nOfOscilations = numberOfOscilations
        self.__oscFunctions = oscFunctions
        self.params = []

    # A f p T
    def __fnTemplate(self,t,*params):
        osc = 0
        trend = 0

        if self.__nOfEstimators > 0:
            trend = self.__trend(t,*params[0:self.__nOfEstimators])
            
        it = 0
        for i in range(self.__nOfEstimators,len(params),3):
            osc += params[i] *self. __oscFunctions[it](params[i+1]*t  + params[i+2])
            it += 1
        
        return trend+osc

    def fit(self,t,y):
        
        estimators = [0.0 for i in range(self.__nOfEstimators-1)]
        estimators.append(np.mean(y))
        oscilations = []
        
        for i in range(self.__nOfOscilations):
            oscilations.append((np.max(y) - np.min(y)) / 4)
            oscilations.append(1.0)
            oscilations.append(0.0)
            
 
        params, _ = curve_fit(self.__fnTemplate,t, y, p0=estimators+oscilations)
        self.params = params
        
    def plot(self,t,df:pd.DataFrame):
        df_temp = df.copy()
        df_temp['pred'] = self.__fnTemplate(t, *self.params)
        df_temp.plot()
        
    def predict(self,t):
        return self.__fnTemplate(t, *self.params)

# %%
random_company = df['Symbol'].sample(1).values[0]
df_curve = df[df['Symbol'] == random_company].copy()
df_curve.set_index('Date', inplace=True)
df_curve = df_curve[[TARGET_COL]]
df_curve = df_curve[df_curve.index.year >= 2024]
days = (df_curve.index - df_curve.index[0]).days.values

# %%
import itertools

def trend(t, a, b, c, d, e):
    return a*t**4 + b*t**3 + c*t**2 + d*t + e
    
trend_configs = [
    (trend, 5, 1, [np.sin]),
    (trend, 5, 2, [np.sin, np.sin]),
    (trend, 5, 2, [np.sin, np.cos]),
    (trend, 5, 3, [np.sin, np.cos, np.sin]),
    (trend, 5, 3, [np.sin, np.sin, np.sin]),
]

flat_trend = lambda t, a: a

flat_configs = [
    (flat_trend, 1, 1, [np.sin]),
    (flat_trend, 1, 2, [np.sin, np.cos]),
    (flat_trend, 1, 3, [np.sin, np.sin, np.sin]),
]

all_configs = trend_configs + flat_configs

n_cols = 2
n_rows = (len(all_configs) + 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 4))
axes = axes.flatten()

df_fit = df_curve.iloc[:-30]
df_pred = df_curve.iloc[-30:]

days_fit = (df_fit.index - df_fit.index[0]).days.values
days_pred = (df_pred.index - df_fit.index[0]).days.values

for i, (trend_fn, n_est, n_osc, osc_fns) in enumerate(all_configs):
    try:
        estimator = CurveEstimator(trend_fn, n_est, n_osc, osc_fns)
        estimator.fit(days_fit, df_fit[TARGET_COL].values)

        df_temp = df_pred.copy()
        df_temp['pred'] = estimator.predict(days_pred)
        df_temp.plot(ax=axes[i])

        osc_names = [f.__name__ for f in osc_fns]
        axes[i].set_title(f"n_est={n_est}, osc={osc_names}")
    except Exception as e:
        axes[i].set_title(f"Config {i} failed: {e}")
                          
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# I. Estimarea dropdown ului pentru o singura companie pe baza SARIMA + NETEZIRE

random_company = df['Symbol'].sample(1).values[0]
df_smooth = df[df['Symbol'] == random_company].copy()
df_smooth.set_index('Date', inplace=True)
df_smooth = df_smooth[[TARGET_COL]]
df_smooth = df_smooth[df_smooth.index.year >= 2016]
df_smooth.plot(title='Original Series')
plt.show()

# %%
window_size = 6
df_smooth['SMA'] = df_smooth[TARGET_COL].rolling(window=window_size).mean()

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df_smooth[df_smooth.index.year >= 2025][TARGET_COL], label='Original Data', color='blue')
plt.plot(df_smooth[df_smooth.index.year >= 2025]['SMA'], label=f'SMA (window={window_size})', color='red')
plt.title('Simple Moving Average Smoothing')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

df_smooth = df_smooth.drop(columns=[TARGET_COL]).dropna()

# %%
# !pip install arch
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from arch.unitroot import PhillipsPerron, ADF
from statsmodels.tsa.stattools import kpss
import statsmodels.api as sm
from scipy import stats
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import root_mean_squared_error,r2_score
import math
from statsmodels.tsa.seasonal import STL
from scipy.stats import boxcox
from statsmodels.tsa.deterministic import Fourier
# Out:
# Collecting arch
#   Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from arch) (2.4.6)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from arch) (2.3.3)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from arch) (0.14.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2026.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->arch) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->arch) (1.17.0)
# Downloading arch-8.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (981 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 27.0 MB/s eta 0:00:0000:01
# Installing collected packages: arch
# Successfully installed arch-8.0.0

# %%
# Seasonal decomposition (additive)
additive_decomposition = seasonal_decompose(df_smooth, model='additive', period=30)
additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

print(additive_decomposition.trend)


pp_test = PhillipsPerron(df_smooth)
print(pp_test.summary())

kpss_stat, p_value, lags, crit = kpss(df_smooth, regression='c', nlags='auto')
print(f"KPSS Statistic: {kpss_stat}")
print(f"p-value: {p_value}")
print(f"Critical Values: {crit}")

adf = ADF(df_smooth)
print(adf.summary().as_text())

n_lags = min(len(df_smooth) // 4, 40)

plot_acf(df_smooth['SMA'], lags=n_lags)
plt.title("ACF before differencing")
plt.show()

plot_pacf(df_smooth['SMA'], lags=n_lags, method='ywm')
plt.title("PACF before differencing")
plt.show()

df_orig = df_smooth.copy()
df_smooth = df_smooth.diff(12).dropna()
df_smooth.plot()
plt.show()
# Out:
# Date
# 2016-01-11   NaN
# 2016-01-12   NaN
# 2016-01-13   NaN
# 2016-01-14   NaN
# 2016-01-15   NaN
#               ..
# 2026-04-07   NaN
# 2026-04-08   NaN
# 2026-04-09   NaN
# 2026-04-10   NaN
# 2026-04-13   NaN
# Name: trend, Length: 2550, dtype: float64
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -6.541
# P-value                         0.000
# Lags                               27
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.43 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
# KPSS Statistic: 0.4395993039791129
# p-value: 0.060086506905554796
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -6.476
# P-value                         0.000
# Lags                               27
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.43 (1%), -2.86 (5%), -2.57 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %%
# !pip install pmdarima
from pmdarima import auto_arima

df_fit = df_smooth.iloc[:-60]
df_pred = df_smooth.iloc[-60:]

model = auto_arima(
    df_fit['SMA'],
    d=0,
    seasonal=True,
    m=5,
    information_criterion='aic',
    stepwise=True,
    trace=True
)

forecast = model.predict(n_periods=60)

plt.figure(figsize=(14, 5))
plt.plot(df_pred.index, df_pred['SMA'], label='Actual', color='green')
plt.plot(df_pred.index, forecast, label='Forecast', color='red', linestyle='--')
plt.title('ARIMA Forecast vs Actual (last 2 months')
plt.legend()
plt.show()
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.4.6)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.3.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2026.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 23.1 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[5] intercept   : AIC=-15669.748, Time=4.85 sec
#  ARIMA(0,0,0)(0,0,0)[5] intercept   : AIC=-4884.064, Time=0.22 sec
#  ARIMA(1,0,0)(1,0,0)[5] intercept   : AIC=-11916.258, Time=0.74 sec
#  ARIMA(0,0,1)(0,0,1)[5] intercept   : AIC=inf, Time=2.84 sec
#  ARIMA(0,0,0)(0,0,0)[5]             : AIC=-4886.056, Time=0.14 sec
#  ARIMA(2,0,2)(0,0,1)[5] intercept   : AIC=-15659.298, Time=0.68 sec
#  ARIMA(2,0,2)(1,0,0)[5] intercept   : AIC=-15659.936, Time=4.00 sec
#  ARIMA(2,0,2)(2,0,1)[5] intercept   : AIC=-15737.695, Time=7.75 sec
#  ARIMA(2,0,2)(2,0,0)[5] intercept   : AIC=-15736.143, Time=6.40 sec
#  ARIMA(2,0,2)(2,0,2)[5] intercept   : AIC=-15691.906, Time=9.44 sec
#  ARIMA(2,0,2)(1,0,2)[5] intercept   : AIC=-15754.465, Time=8.57 sec
#  ARIMA(2,0,2)(0,0,2)[5] intercept   : AIC=-15762.936, Time=7.72 sec
#  ARIMA(1,0,2)(0,0,2)[5] intercept   : AIC=-15053.830, Time=7.36 sec
#  ARIMA(2,0,1)(0,0,2)[5] intercept   : AIC=-15756.623, Time=6.15 sec
#  ARIMA(3,0,2)(0,0,2)[5] intercept   : AIC=-15765.094, Time=9.07 sec
#  ARIMA(3,0,2)(0,0,1)[5] intercept   : AIC=-15664.285, Time=5.00 sec
#  ARIMA(3,0,2)(1,0,2)[5] intercept   : AIC=-15754.144, Time=9.02 sec
#  ARIMA(3,0,2)(1,0,1)[5] intercept   : AIC=-15669.095, Time=5.09 sec
#  ARIMA(3,0,1)(0,0,2)[5] intercept   : AIC=-15758.291, Time=6.77 sec
#  ARIMA(4,0,2)(0,0,2)[5] intercept   : AIC=-15623.895, Time=11.65 sec
#  ARIMA(3,0,3)(0,0,2)[5] intercept   : AIC=-15758.177, Time=9.16 sec
#  ARIMA(2,0,3)(0,0,2)[5] intercept   : AIC=-15757.135, Time=7.06 sec
#  ARIMA(4,0,1)(0,0,2)[5] intercept   : AIC=-15764.049, Time=7.36 sec
#  ARIMA(4,0,3)(0,0,2)[5] intercept   : AIC=-16067.275, Time=9.47 sec
#  ARIMA(4,0,3)(0,0,1)[5] intercept   : AIC=-15970.055, Time=7.28 sec
#  ARIMA(4,0,3)(1,0,2)[5] intercept   : AIC=-16000.351, Time=12.76 sec
#  ARIMA(4,0,3)(1,0,1)[5] intercept   : AIC=-15975.837, Time=8.21 sec
#  ARIMA(4,0,4)(0,0,2)[5] intercept   : AIC=-16012.535, Time=10.87 sec
#  ARIMA(3,0,4)(0,0,2)[5] intercept   : AIC=-15764.279, Time=10.20 sec
#  ARIMA(4,0,3)(0,0,2)[5]             : AIC=-16062.158, Time=7.00 sec
#
# Best model:  ARIMA(4,0,3)(0,0,2)[5] intercept
# Total fit time: 202.860 seconds
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
#III. Analiza serii de timp multivariate pentru o singura companie
from statsmodels.tsa.stattools import adfuller, coint
from statsmodels.tsa.api import VAR
from statsmodels.tsa.vector_ar.vecm import coint_johansen, VECM

random_company = df['Symbol'].sample(1).values[0]
df_multi = df[df['Symbol'] == random_company].copy().drop(columns=['Symbol'])
df_multi = df_multi[[TARGET_COL, "Date"] + FEATURE_COLS]
df_multi.set_index('Date', inplace=True)
df_multi = df_multi[df_multi.index.year >= 2016]

df_multi.info()

# Test de cointegrare
for i in range(len(df_multi.columns)-1):
    for j in range(i+1, len(df_multi.columns)):
        col1 = df_multi.columns[i]
        col2 = df_multi.columns[j]
        if col1 != TARGET_COL and col2 != TARGET_COL:
            continue
        
        coint_t, p_value, crit_values = coint(df_multi[col1], df_multi[col2])
        print(f"{col1} si {col2}")
        print("\nCointegration Test Result:")
        print(f"T-statistic: {coint_t}")
        print(f"P-value: {p_value}")
        print(f"Critical Values: {crit_values}")
        if p_value < 0.05:
            print("✅ The series are cointegrated.")
        else:
            print("❌ The series are NOT cointegrated.")

for it in df_multi.columns:
    chk = adfuller(df_multi[it],autolag='AIC')
    if chk[1] < 0.05:
        print(f"{it} e stationara")
    else:
        print(f"{it} e nestationara")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2544 entries, 2016-01-20 to 2026-04-13
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   future_max_drawdown_10d  2544 non-null   float64
#  1   daily_return             2544 non-null   float64
#  2   log_return_1d            2544 non-null   float64
#  3   return_5d                2544 non-null   float64
#  4   return_20d               2544 non-null   float64
#  5   intraday_range           2544 non-null   float64
#  6   open_close_return        2544 non-null   float64
#  7   volume_change_1d         2544 non-null   float64
#  8   volume_ratio_20d         2544 non-null   float64
#  9   ma_5_ratio               2544 non-null   float64
#  10  ma_20_ratio              2544 non-null   float64
#  11  ma_60_ratio              2544 non-null   float64
#  12  volatility_5d            2544 non-null   float64
#  13  volatility_10d           2544 non-null   float64
#  14  volatility_20d           2544 non-null   float64
#  15  volatility_60d           2544 non-null   float64
#  16  past_max_drawdown_10d    2544 non-null   float64
#  17  past_max_drawdown_20d    2544 non-null   float64
#  18  past_max_drawdown_60d    2544 non-null   float64
# dtypes: float64(19)
# memory usage: 397.5 KB
# future_max_drawdown_10d si daily_return
#
# Cointegration Test Result:
# T-statistic: -9.824181934820457
# P-value: 6.903645390377031e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si log_return_1d
#
# Cointegration Test Result:
# T-statistic: -9.824581201520347
# P-value: 6.887587794127206e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si return_5d
#
# Cointegration Test Result:
# T-statistic: -9.897200078975233
# P-value: 4.511146435954394e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si return_20d
#
# Cointegration Test Result:
# T-statistic: -9.752407395988042
# P-value: 1.0496115587736978e-15
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si intraday_range
#
# Cointegration Test Result:
# T-statistic: -10.774617219486073
# P-value: 2.940383197403506e-18
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si open_close_return
#
# Cointegration Test Result:
# T-statistic: -9.794731658284713
# P-value: 8.197859760141934e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volume_change_1d
#
# Cointegration Test Result:
# T-statistic: -10.454193772086928
# P-value: 1.8110958669396362e-17
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volume_ratio_20d
#
# Cointegration Test Result:
# T-statistic: -9.903432778491009
# P-value: 4.35039696817537e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_5_ratio
#
# Cointegration Test Result:
# T-statistic: -9.864911981724365
# P-value: 5.444523997798977e-16
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_20_ratio
#
# Cointegration Test Result:
# T-statistic: -10.395438464820208
# P-value: 2.534738521361706e-17
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si ma_60_ratio
#
# Cointegration Test Result:
# T-statistic: -10.341805159798684
# P-value: 3.447446775036056e-17
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_5d
#
# Cointegration Test Result:
# T-statistic: -10.365924374406475
# P-value: 3.00191376420154e-17
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_10d
#
# Cointegration Test Result:
# T-statistic: -11.013706593010312
# P-value: 7.717840211400999e-19
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_20d
#
# Cointegration Test Result:
# T-statistic: -10.948407127812402
# P-value: 1.1101803570931623e-18
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si volatility_60d
#
# Cointegration Test Result:
# T-statistic: -10.585684064419114
# P-value: 8.56119711576295e-18
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_10d
#
# Cointegration Test Result:
# T-statistic: -10.851231072538798
# P-value: 1.9117838610085246e-18
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_20d
#
# Cointegration Test Result:
# T-statistic: -11.12529564880737
# P-value: 4.1596827961878676e-19
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d si past_max_drawdown_60d
#
# Cointegration Test Result:
# T-statistic: -10.802798927347457
# P-value: 2.509249477814504e-18
# Critical Values: [-3.90075187 -3.33853377 -3.04611821]
# ✅ The series are cointegrated.
# future_max_drawdown_10d e stationara
# daily_return e stationara
# log_return_1d e stationara
# return_5d e stationara
# return_20d e stationara
# intraday_range e stationara
# open_close_return e stationara
# volume_change_1d e stationara
# volume_ratio_20d e stationara
# ma_5_ratio e stationara
# ma_20_ratio e stationara
# ma_60_ratio e stationara
# volatility_5d e stationara
# volatility_10d e stationara
# volatility_20d e stationara
# volatility_60d e stationara
# past_max_drawdown_10d e stationara
# past_max_drawdown_20d e stationara
# past_max_drawdown_60d e stationara

# %%
df_train = df_multi.iloc[:-60]
df_test = df_multi.iloc[-60:]

model = VAR(df_train)

lag_results = model.select_order(maxlags=15)
print(lag_results.summary())

best_lag = lag_results.aic
print(f"Best lag by AIC: {best_lag}")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -160.2      -160.2   2.676e-70      -160.2
# 1       -200.5      -199.7   8.011e-88      -200.2
# 2       -201.8      -200.0   2.303e-88      -201.2
# 3       -204.4     -201.8*   1.725e-89      -203.4
# 4       -205.1      -201.7   8.457e-90      -203.8
# 5       -206.0      -201.7   3.515e-90      -204.4
# 6       -206.2      -201.0   2.850e-90      -204.3
# 7       -206.3      -200.4   2.436e-90      -204.2
# 8       -206.6      -199.7   1.942e-90      -204.1
# 9       -207.0      -199.3   1.314e-90      -204.2
# 10      -207.4      -198.8   8.894e-91      -204.3
# 11      -207.9      -198.5   5.185e-91     -204.5*
# 12      -208.0      -197.7   4.889e-91      -204.2
# 13      -207.9      -196.8   5.060e-91      -203.9
# 14      -208.0      -196.0   4.822e-91      -203.6
# 15     -208.2*      -195.4  4.004e-91*      -203.5
# --------------------------------------------------
# Best lag by AIC: 15

# %%
fitted = model.fit(best_lag)

forecast_input = df_train.values[-best_lag:]
forecast = fitted.forecast(forecast_input, steps=60)
forecast_df = pd.DataFrame(forecast, index=df_test.index, columns=df_multi.columns)

plt.figure(figsize=(12, 4))
plt.plot(df_test.index, df_test[TARGET_COL], label='Actual', color='green')
plt.plot(forecast_df.index, forecast_df[TARGET_COL], label='Forecast', color='red', linestyle='--')
plt.title(f'VAR Forecast vs Actual - {TARGET_COL}')
plt.legend()
plt.show()

# %%
# IV. Regresie cu date de tip panel
# !pip install linearmodels
from linearmodels.panel import PanelOLS

df_panel = df.copy()
df_panel = df_panel[df_panel['Date'].dt.year >= 2016]
df_panel = df_panel.set_index(['Symbol', 'Date'])
df_panel = df_panel[[TARGET_COL] + FEATURE_COLS].dropna()

df_panel['target_lag1'] = df_panel.groupby('Symbol')[TARGET_COL].shift(1)
df_panel = df_panel.dropna()

split_date = df_panel.index.get_level_values('Date').unique().sort_values()[-180]

df_train = df_panel[df_panel.index.get_level_values('Date') < split_date]
df_test  = df_panel[df_panel.index.get_level_values('Date') >= split_date]

features = FEATURE_COLS + ['target_lag1']

exog_train = df_train[features]
endog_train = df_train[TARGET_COL]

model = PanelOLS(endog_train, exog_train, entity_effects=True)
fitted = model.fit(cov_type='robust')
print(fitted.summary)

preds = fitted.predict(df_test[features])
df_test = df_test.copy()
df_test['pred'] = preds.values
# Out:
# Collecting linearmodels
#   Downloading linearmodels-7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (2.4.6)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (0.14.6)
# Requirement already satisfied: mypy_extensions>=0.4 in /usr/local/lib/python3.12/dist-packages (from linearmodels) (1.1.0)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.2.1 (from linearmodels)
#   Downloading formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.2.1->linearmodels)
#   Downloading interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=1.2.1->linearmodels) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->linearmodels) (2026.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->linearmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->linearmodels) (26.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->linearmodels) (1.17.0)
# Downloading linearmodels-7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 39.4 MB/s eta 0:00:0000:01
# Downloading formulaic-1.2.2-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 10.2 MB/s eta 0:00:00
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading interface_meta-2.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: interface-meta, pyhdfe, formulaic, linearmodels
# Successfully installed formulaic-1.2.2 interface-meta-2.0.1 linearmodels-7.0 pyhdfe-0.2.0
#                              PanelOLS Estimation Summary
# =====================================================================================
# Dep. Variable:     future_max_drawdown_10d   R-squared:                        0.9157
# Estimator:                        PanelOLS   R-squared (Between):              0.9483
# No. Observations:                    95071   R-squared (Within):               0.9157
# Date:                     Sat, Jun 13 2026   R-squared (Overall):              0.9258
# Time:                             15:13:54   Log-likelihood                 2.638e+05
# Cov. Estimator:                     Robust
#                                              F-statistic:                   5.434e+04
# Entities:                               49   P-value                           0.0000
# Avg Obs:                            1940.2   Distribution:                F(19,95003)
# Min Obs:                            21.000
# Max Obs:                            2374.0   F-statistic (robust):          1.997e+04
#                                              P-value                           0.0000
# Time periods:                         2374   Distribution:                F(19,95003)
# Avg Obs:                            40.047
# Min Obs:                            34.000
# Max Obs:                            49.000
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# daily_return              0.5094     0.0254     20.019     0.0000      0.4595      0.5593
# log_return_1d             0.1688     0.0184     9.1942     0.0000      0.1328      0.2048
# return_5d                 0.0057     0.0029     1.9668     0.0492   1.974e-05      0.0114
# return_20d                0.0041     0.0014     2.8181     0.0048      0.0012      0.0069
# intraday_range           -0.1150     0.0074    -15.616     0.0000     -0.1295     -0.1006
# open_close_return         0.0822     0.0108     7.6226     0.0000      0.0611      0.1034
# volume_change_1d         -0.0011     0.0002    -5.0739     0.0000     -0.0015     -0.0007
# volume_ratio_20d         -0.0024     0.0002    -11.095     0.0000     -0.0028     -0.0019
# ma_5_ratio               -0.0139     0.0066    -2.1132     0.0346     -0.0267     -0.0010
# ma_20_ratio               0.0061     0.0031     1.9648     0.0494    1.49e-05      0.0121
# ma_60_ratio               0.0022     0.0012     1.7822     0.0747     -0.0002      0.0046
# volatility_5d            -0.0885     0.0088    -10.004     0.0000     -0.1058     -0.0711
# volatility_10d           -0.0074     0.0097    -0.7584     0.4482     -0.0264      0.0117
# volatility_20d           -0.0605     0.0098    -6.1639     0.0000     -0.0797     -0.0412
# volatility_60d            0.0280     0.0098     2.8569     0.0043      0.0088      0.0472
# past_max_drawdown_10d     0.0140     0.0036     3.9336     0.0001      0.0070      0.0210
# past_max_drawdown_20d     0.0188     0.0030     6.3474     0.0000      0.0130      0.0247
# past_max_drawdown_60d     0.0004     0.0015     0.2376     0.8122     -0.0026      0.0033
# target_lag1               1.0395     0.0018     592.37     0.0000      1.0361      1.0430
# =========================================================================================
#
# F-test for Poolability: 0.9211
# P-value: 0.6287
# Distribution: F(48,95003)
#
# Included effects: Entity

# %%
sample_company = df_test.index.get_level_values('Symbol').unique()[0]
df_sample = df_test.xs(sample_company, level='Symbol')

plt.figure(figsize=(12, 4))
plt.plot(df_sample.index, df_sample[TARGET_COL], label='Actual', color='green')
plt.plot(df_sample.index, df_sample['pred'], label='Predicted', color='red', linestyle='--')
plt.title(f'PanelOLS Forecast vs Actual - {sample_company} (last 180 days)')
plt.legend()
plt.show()

# %%
# V. Predictie folosing retele neuronale
import tensorflow as tf
from sklearn.preprocessing import StandardScaler


SEQ_LEN = 60

def make_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i, :-1])
        y.append(data[i, -1])
    return np.array(X), np.array(y)

all_X_train, all_y_train = [], []
all_X_test,  all_y_test  = [], []
test_indices = {}

scaler = StandardScaler()

for company in df_panel.index.get_level_values('Symbol').unique():
    df_company = df_panel.xs(company, level='Symbol').sort_index()
    df_company = df_company[features + [TARGET_COL]].dropna()

    if len(df_company) < SEQ_LEN + 180:
        continue

    data_scaled = scaler.fit_transform(df_company.values)

    split_idx = len(df_company) - 180
    train_data = data_scaled[:split_idx]
    test_data  = data_scaled[split_idx - SEQ_LEN:]

    X_train, y_train = make_sequences(train_data, SEQ_LEN)
    X_test,  y_test  = make_sequences(test_data,  SEQ_LEN)

    all_X_train.append(X_train)
    all_y_train.append(y_train)
    all_X_test.append(X_test)
    all_y_test.append(y_test)
    test_indices[company] = df_company.index[-180:]

X_train = np.concatenate(all_X_train, axis=0)
y_train = np.concatenate(all_y_train, axis=0)
X_test  = np.concatenate(all_X_test,  axis=0)
y_test  = np.concatenate(all_y_test,  axis=0)

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (92186, 60, 19), Test: (8460, 60, 19)

# %%
def buildLSTM(seq_len, n_features):
    model_lstm = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(seq_len, n_features)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)
    ])
    model_lstm.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model_lstm.summary()
    return model_lstm

def buildGRU(seq_len, n_features):
    model_gru = tf.keras.Sequential([
        tf.keras.layers.GRU(64, return_sequences=True, input_shape=(seq_len, n_features)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.GRU(32),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)
    ])
    model_gru.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model_gru.summary()
    return model_gru

def buildCNNGRU(seq_len, n_features, hidden_size=64, dropout=0.2):
    inputs = tf.keras.Input(shape=(seq_len, n_features))
    
    x = tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", activation="relu")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.GRU(hidden_size, return_sequences=True, dropout=dropout)(x)
    x = tf.keras.layers.GRU(hidden_size // 2, dropout=dropout)(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model.summary()
    return model
    
def train(model, X_train, y_train, save_path, epochs=50, batch_size=256, validation_split=0.1, patience=3):
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=validation_split,
        callbacks=[
            tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=patience, factor=0.5, verbose=1),
            tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=patience * 2 + 1, restore_best_weights=True, verbose=1),
            tf.keras.callbacks.ModelCheckpoint(save_path, monitor="val_loss", save_best_only=True, verbose=1),
        ]
    )
    return history


def plot(history, model, X_test, y_test, all_X_test, test_indices, scaler, features, sample_company=None):
    plt.figure(figsize=(10, 3))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('LSTM Training Loss')
    plt.legend()
    plt.show()

    if sample_company is None:
        sample_company = list(test_indices.keys())[0]
    company_idx = list(test_indices.keys()).index(sample_company)

    start = sum(len(all_X_test[i]) for i in range(company_idx))
    end   = start + len(all_X_test[company_idx])

    X_company = X_test[start:end]
    y_company = y_test[start:end]
    preds = model.predict(X_company).flatten()

    n_features = len(features) + 1
    dummy = np.zeros((len(preds), n_features))
    dummy[:, -1] = preds
    preds_unscaled = scaler.inverse_transform(dummy)[:, -1]

    dummy2 = np.zeros((len(y_company), n_features))
    dummy2[:, -1] = y_company
    actual_unscaled = scaler.inverse_transform(dummy2)[:, -1]

    plt.figure(figsize=(12, 4))
    plt.plot(test_indices[sample_company], actual_unscaled, label='Actual', color='green')
    plt.plot(test_indices[sample_company], preds_unscaled, label='Predicted', color='red', linestyle='--')
    plt.title(f'Model Forecast vs Actual - {sample_company} (last 180 days)')
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

SAVE_DIR = "/kaggle/working/saved_models"
os.makedirs(SAVE_DIR, exist_ok=True)

strategy = tf.distribute.MirroredStrategy()
print(f"GPUs in use: {strategy.num_replicas_in_sync}")
NUM_GPUS = strategy.num_replicas_in_sync

with strategy.scope():
    model_configs = {
        'LSTM':   buildLSTM(seq_len=SEQ_LEN,   n_features=X_train.shape[2]),
        'GRU':    buildGRU(seq_len=SEQ_LEN,    n_features=X_train.shape[2]),
        'CNNGRU': buildCNNGRU(seq_len=SEQ_LEN, n_features=X_train.shape[2]),
    }

histories = {}
metrics   = {}

for name, model in model_configs.items():
    print(f"\n{'='*40}\nTraining {name}\n{'='*40}")

    history = train(model, X_train, y_train, save_path = os.path.join(SAVE_DIR, f"{name}.keras"), batch_size=256 * NUM_GPUS)
    histories[name] = history

    plot(history, model, X_test, y_test, all_X_test, test_indices, scaler, features)

    preds = model.predict(X_test).flatten()
    n_feat = len(features) + 1

    dummy = np.zeros((len(preds), n_feat))
    dummy[:, -1] = preds
    preds_unscaled = scaler.inverse_transform(dummy)[:, -1]

    dummy2 = np.zeros((len(y_test), n_feat))
    dummy2[:, -1] = y_test
    actual_unscaled = scaler.inverse_transform(dummy2)[:, -1]

    metrics[name] = {
        'MSE':  mean_squared_error(actual_unscaled, preds_unscaled),
        'MAE':  mean_absolute_error(actual_unscaled, preds_unscaled),
        'RMSE': np.sqrt(mean_squared_error(actual_unscaled, preds_unscaled)),
    }

metrics_df = pd.DataFrame(metrics).T
print("\n=== Model Comparison ===")
print(metrics_df.sort_values('RMSE'))

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, metric in zip(axes, ['MSE', 'MAE', 'RMSE']):
    metrics_df[metric].plot(kind='bar', ax=ax, color=['blue', 'orange', 'green'])
    ax.set_title(metric)
    ax.set_xticklabels(metrics_df.index, rotation=0)
plt.suptitle('Model Comparison')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
for name, history in histories.items():
    plt.plot(history.history['val_loss'], label=f'{name} Val Loss')
plt.title('Validation Loss Comparison')
plt.legend()
plt.show()

metrics_df.to_csv(os.path.join(SAVE_DIR, 'metrics.csv'))
print(f"Metrics saved to {SAVE_DIR}/metrics.csv")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# GPUs in use: 2
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 60, 64)         │        21,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,953 (132.63 KB)
#  Trainable params: 33,953 (132.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_8 (GRU)                     │ (None, 60, 64)         │        16,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_9 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,761 (100.63 KB)
#  Trainable params: 25,761 (100.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 60, 19)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 60, 64)         │         3,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 60, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 60, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 60, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_10 (GRU)                    │ (None, 60, 64)         │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,121 (207.50 KB)
#  Trainable params: 52,865 (206.50 KB)
#  Non-trainable params: 256 (1.00 KB)
# ========================================
# Training LSTM
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7254 - mae: 0.5605
# Epoch 1: val_loss improved from None to 0.33702, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.5412 - mae: 0.4805 - val_loss: 0.3370 - val_mae: 0.3984 - learning_rate: 0.0010
# Epoch 2/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3348 - mae: 0.3755
# Epoch 2: val_loss improved from 0.33702 to 0.29564, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.3262 - mae: 0.3695 - val_loss: 0.2956 - val_mae: 0.3706 - learning_rate: 0.0010
# Epoch 3/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3005 - mae: 0.3527
# Epoch 3: val_loss improved from 0.29564 to 0.27799, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.3001 - mae: 0.3512 - val_loss: 0.2780 - val_mae: 0.3633 - learning_rate: 0.0010
# Epoch 4/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2824 - mae: 0.3450
# Epoch 4: val_loss improved from 0.27799 to 0.27274, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2838 - mae: 0.3423 - val_loss: 0.2727 - val_mae: 0.3530 - learning_rate: 0.0010
# Epoch 5/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2742 - mae: 0.3354
# Epoch 5: val_loss improved from 0.27274 to 0.26687, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 5: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2790 - mae: 0.3368 - val_loss: 0.2669 - val_mae: 0.3483 - learning_rate: 0.0010
# Epoch 6/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2777 - mae: 0.3330
# Epoch 6: val_loss did not improve from 0.26687
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2724 - mae: 0.3327 - val_loss: 0.2688 - val_mae: 0.3520 - learning_rate: 0.0010
# Epoch 7/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2523 - mae: 0.3293
# Epoch 7: val_loss did not improve from 0.26687
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2673 - mae: 0.3303 - val_loss: 0.2685 - val_mae: 0.3560 - learning_rate: 0.0010
# Epoch 8/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2556 - mae: 0.3272
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_loss did not improve from 0.26687
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2624 - mae: 0.3276 - val_loss: 0.2693 - val_mae: 0.3532 - learning_rate: 0.0010
# Epoch 9/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2601 - mae: 0.3267
# Epoch 9: val_loss improved from 0.26687 to 0.25881, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 9: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2574 - mae: 0.3249 - val_loss: 0.2588 - val_mae: 0.3456 - learning_rate: 5.0000e-04
# Epoch 10/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2516 - mae: 0.3258
# Epoch 10: val_loss did not improve from 0.25881
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2531 - mae: 0.3234 - val_loss: 0.2598 - val_mae: 0.3492 - learning_rate: 5.0000e-04
# Epoch 11/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2511 - mae: 0.3231
# Epoch 11: val_loss improved from 0.25881 to 0.25875, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 11: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2525 - mae: 0.3227 - val_loss: 0.2588 - val_mae: 0.3478 - learning_rate: 5.0000e-04
# Epoch 12/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2522 - mae: 0.3218
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_loss did not improve from 0.25875
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2532 - mae: 0.3227 - val_loss: 0.2602 - val_mae: 0.3451 - learning_rate: 5.0000e-04
# Epoch 13/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2603 - mae: 0.3216
# Epoch 13: val_loss improved from 0.25875 to 0.25667, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 13: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2479 - mae: 0.3200 - val_loss: 0.2567 - val_mae: 0.3444 - learning_rate: 2.5000e-04
# Epoch 14/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2386 - mae: 0.3186
# Epoch 14: val_loss improved from 0.25667 to 0.25496, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 14: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2461 - mae: 0.3191 - val_loss: 0.2550 - val_mae: 0.3412 - learning_rate: 2.5000e-04
# Epoch 15/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2359 - mae: 0.3178
# Epoch 15: val_loss improved from 0.25496 to 0.25297, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 15: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2439 - mae: 0.3178 - val_loss: 0.2530 - val_mae: 0.3390 - learning_rate: 2.5000e-04
# Epoch 16/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2522 - mae: 0.3189
# Epoch 16: val_loss did not improve from 0.25297
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2448 - mae: 0.3183 - val_loss: 0.2540 - val_mae: 0.3442 - learning_rate: 2.5000e-04
# Epoch 17/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2388 - mae: 0.3174
# Epoch 17: val_loss did not improve from 0.25297
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2419 - mae: 0.3178 - val_loss: 0.2530 - val_mae: 0.3404 - learning_rate: 2.5000e-04
# Epoch 18/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2368 - mae: 0.3157
# Epoch 18: val_loss improved from 0.25297 to 0.25183, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 18: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.2408 - mae: 0.3168 - val_loss: 0.2518 - val_mae: 0.3408 - learning_rate: 2.5000e-04
# Epoch 19/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2367 - mae: 0.3170
# Epoch 19: val_loss did not improve from 0.25183
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2409 - mae: 0.3166 - val_loss: 0.2526 - val_mae: 0.3388 - learning_rate: 2.5000e-04
# Epoch 20/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2382 - mae: 0.3150
# Epoch 20: val_loss did not improve from 0.25183
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2390 - mae: 0.3161 - val_loss: 0.2543 - val_mae: 0.3425 - learning_rate: 2.5000e-04
# Epoch 21/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2209 - mae: 0.3131
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 21: val_loss did not improve from 0.25183
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2384 - mae: 0.3154 - val_loss: 0.2524 - val_mae: 0.3437 - learning_rate: 2.5000e-04
# Epoch 22/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2307 - mae: 0.3131
# Epoch 22: val_loss improved from 0.25183 to 0.25172, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 22: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2358 - mae: 0.3148 - val_loss: 0.2517 - val_mae: 0.3406 - learning_rate: 1.2500e-04
# Epoch 23/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2389 - mae: 0.3146
# Epoch 23: val_loss improved from 0.25172 to 0.25001, saving model to /kaggle/working/saved_models/LSTM.keras
#
# Epoch 23: finished saving model to /kaggle/working/saved_models/LSTM.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2357 - mae: 0.3141 - val_loss: 0.2500 - val_mae: 0.3392 - learning_rate: 1.2500e-04
# Epoch 24/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2284 - mae: 0.3134
# Epoch 24: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2339 - mae: 0.3133 - val_loss: 0.2542 - val_mae: 0.3435 - learning_rate: 1.2500e-04
# Epoch 25/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2249 - mae: 0.3101
# Epoch 25: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2346 - mae: 0.3138 - val_loss: 0.2519 - val_mae: 0.3396 - learning_rate: 1.2500e-04
# Epoch 26/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2333 - mae: 0.3136
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 26: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2345 - mae: 0.3132 - val_loss: 0.2515 - val_mae: 0.3408 - learning_rate: 1.2500e-04
# Epoch 27/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2530 - mae: 0.3139
# Epoch 27: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2334 - mae: 0.3129 - val_loss: 0.2505 - val_mae: 0.3392 - learning_rate: 6.2500e-05
# Epoch 28/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2254 - mae: 0.3129
# Epoch 28: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2319 - mae: 0.3132 - val_loss: 0.2505 - val_mae: 0.3382 - learning_rate: 6.2500e-05
# Epoch 29/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2274 - mae: 0.3112
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 29: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2319 - mae: 0.3117 - val_loss: 0.2506 - val_mae: 0.3395 - learning_rate: 6.2500e-05
# Epoch 30/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2553 - mae: 0.3144
# Epoch 30: val_loss did not improve from 0.25001
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2319 - mae: 0.3121 - val_loss: 0.2500 - val_mae: 0.3389 - learning_rate: 3.1250e-05
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
#
# ========================================
# Training GRU
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 8 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5801 - mae: 0.4944
# Epoch 1: val_loss improved from None to 0.31049, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.4536 - mae: 0.4286 - val_loss: 0.3105 - val_mae: 0.3703 - learning_rate: 0.0010
# Epoch 2/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3290 - mae: 0.3650
# Epoch 2: val_loss improved from 0.31049 to 0.28584, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.3221 - mae: 0.3609 - val_loss: 0.2858 - val_mae: 0.3627 - learning_rate: 0.0010
# Epoch 3/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3143 - mae: 0.3525
# Epoch 3: val_loss improved from 0.28584 to 0.27609, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.3001 - mae: 0.3483 - val_loss: 0.2761 - val_mae: 0.3566 - learning_rate: 0.0010
# Epoch 4/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3016 - mae: 0.3449
# Epoch 4: val_loss did not improve from 0.27609
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2899 - mae: 0.3424 - val_loss: 0.2761 - val_mae: 0.3574 - learning_rate: 0.0010
# Epoch 5/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2715 - mae: 0.3364
# Epoch 5: val_loss improved from 0.27609 to 0.26483, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 5: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2817 - mae: 0.3376 - val_loss: 0.2648 - val_mae: 0.3486 - learning_rate: 0.0010
# Epoch 6/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2705 - mae: 0.3362
# Epoch 6: val_loss improved from 0.26483 to 0.26389, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 6: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2775 - mae: 0.3362 - val_loss: 0.2639 - val_mae: 0.3451 - learning_rate: 0.0010
# Epoch 7/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2814 - mae: 0.3351
# Epoch 7: val_loss improved from 0.26389 to 0.26187, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 7: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2737 - mae: 0.3332 - val_loss: 0.2619 - val_mae: 0.3481 - learning_rate: 0.0010
# Epoch 8/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2742 - mae: 0.3326
# Epoch 8: val_loss did not improve from 0.26187
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2683 - mae: 0.3308 - val_loss: 0.2629 - val_mae: 0.3492 - learning_rate: 0.0010
# Epoch 9/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2639 - mae: 0.3297
# Epoch 9: val_loss improved from 0.26187 to 0.25733, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 9: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2664 - mae: 0.3296 - val_loss: 0.2573 - val_mae: 0.3454 - learning_rate: 0.0010
# Epoch 10/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2584 - mae: 0.3288
# Epoch 10: val_loss did not improve from 0.25733
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2639 - mae: 0.3293 - val_loss: 0.2582 - val_mae: 0.3456 - learning_rate: 0.0010
# Epoch 11/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2676 - mae: 0.3277
# Epoch 11: val_loss improved from 0.25733 to 0.25472, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 11: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2612 - mae: 0.3269 - val_loss: 0.2547 - val_mae: 0.3432 - learning_rate: 0.0010
# Epoch 12/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2531 - mae: 0.3256
# Epoch 12: val_loss improved from 0.25472 to 0.25145, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 12: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.2553 - mae: 0.3247 - val_loss: 0.2515 - val_mae: 0.3389 - learning_rate: 0.0010
# Epoch 13/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2596 - mae: 0.3263
# Epoch 13: val_loss improved from 0.25145 to 0.25108, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 13: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2572 - mae: 0.3252 - val_loss: 0.2511 - val_mae: 0.3410 - learning_rate: 0.0010
# Epoch 14/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2576 - mae: 0.3259
# Epoch 14: val_loss did not improve from 0.25108
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2526 - mae: 0.3239 - val_loss: 0.2514 - val_mae: 0.3420 - learning_rate: 0.0010
# Epoch 15/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2713 - mae: 0.3253
# Epoch 15: val_loss did not improve from 0.25108
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2504 - mae: 0.3226 - val_loss: 0.2555 - val_mae: 0.3434 - learning_rate: 0.0010
# Epoch 16/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2446 - mae: 0.3222
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_loss did not improve from 0.25108
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2471 - mae: 0.3204 - val_loss: 0.2517 - val_mae: 0.3363 - learning_rate: 0.0010
# Epoch 17/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2595 - mae: 0.3206
# Epoch 17: val_loss improved from 0.25108 to 0.24532, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 17: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2430 - mae: 0.3178 - val_loss: 0.2453 - val_mae: 0.3389 - learning_rate: 5.0000e-04
# Epoch 18/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2439 - mae: 0.3196
# Epoch 18: val_loss improved from 0.24532 to 0.24411, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 18: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2429 - mae: 0.3178 - val_loss: 0.2441 - val_mae: 0.3361 - learning_rate: 5.0000e-04
# Epoch 19/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2473 - mae: 0.3183
# Epoch 19: val_loss did not improve from 0.24411
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2404 - mae: 0.3170 - val_loss: 0.2453 - val_mae: 0.3375 - learning_rate: 5.0000e-04
# Epoch 20/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2415 - mae: 0.3166
# Epoch 20: val_loss improved from 0.24411 to 0.24213, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 20: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2392 - mae: 0.3155 - val_loss: 0.2421 - val_mae: 0.3363 - learning_rate: 5.0000e-04
# Epoch 21/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2372 - mae: 0.3171
# Epoch 21: val_loss improved from 0.24213 to 0.24123, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 21: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2374 - mae: 0.3156 - val_loss: 0.2412 - val_mae: 0.3333 - learning_rate: 5.0000e-04
# Epoch 22/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2385 - mae: 0.3165
# Epoch 22: val_loss did not improve from 0.24123
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2399 - mae: 0.3161 - val_loss: 0.2432 - val_mae: 0.3342 - learning_rate: 5.0000e-04
# Epoch 23/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2344 - mae: 0.3135
# Epoch 23: val_loss did not improve from 0.24123
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2342 - mae: 0.3139 - val_loss: 0.2430 - val_mae: 0.3383 - learning_rate: 5.0000e-04
# Epoch 24/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2406 - mae: 0.3152
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_loss did not improve from 0.24123
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2354 - mae: 0.3139 - val_loss: 0.2413 - val_mae: 0.3341 - learning_rate: 5.0000e-04
# Epoch 25/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2442 - mae: 0.3147
# Epoch 25: val_loss improved from 0.24123 to 0.24115, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 25: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2317 - mae: 0.3128 - val_loss: 0.2411 - val_mae: 0.3325 - learning_rate: 2.5000e-04
# Epoch 26/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2161 - mae: 0.3092
# Epoch 26: val_loss improved from 0.24115 to 0.23991, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 26: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2308 - mae: 0.3118 - val_loss: 0.2399 - val_mae: 0.3333 - learning_rate: 2.5000e-04
# Epoch 27/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2282 - mae: 0.3130
# Epoch 27: val_loss improved from 0.23991 to 0.23886, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 27: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2285 - mae: 0.3116 - val_loss: 0.2389 - val_mae: 0.3318 - learning_rate: 2.5000e-04
# Epoch 28/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2355 - mae: 0.3120
# Epoch 28: val_loss did not improve from 0.23886
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2286 - mae: 0.3105 - val_loss: 0.2406 - val_mae: 0.3362 - learning_rate: 2.5000e-04
# Epoch 29/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2313 - mae: 0.3105
# Epoch 29: val_loss did not improve from 0.23886
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2281 - mae: 0.3108 - val_loss: 0.2416 - val_mae: 0.3341 - learning_rate: 2.5000e-04
# Epoch 30/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2397 - mae: 0.3122
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 30: val_loss did not improve from 0.23886
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2298 - mae: 0.3116 - val_loss: 0.2409 - val_mae: 0.3326 - learning_rate: 2.5000e-04
# Epoch 31/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2378 - mae: 0.3101
# Epoch 31: val_loss did not improve from 0.23886
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2254 - mae: 0.3088 - val_loss: 0.2396 - val_mae: 0.3340 - learning_rate: 1.2500e-04
# Epoch 32/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2302 - mae: 0.3090
# Epoch 32: val_loss did not improve from 0.23886
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2249 - mae: 0.3092 - val_loss: 0.2395 - val_mae: 0.3339 - learning_rate: 1.2500e-04
# Epoch 33/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2163 - mae: 0.3073
# Epoch 33: val_loss improved from 0.23886 to 0.23840, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 33: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2257 - mae: 0.3092 - val_loss: 0.2384 - val_mae: 0.3335 - learning_rate: 1.2500e-04
# Epoch 34/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2126 - mae: 0.3081
# Epoch 34: val_loss improved from 0.23840 to 0.23830, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 34: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2247 - mae: 0.3090 - val_loss: 0.2383 - val_mae: 0.3335 - learning_rate: 1.2500e-04
# Epoch 35/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2249 - mae: 0.3096
# Epoch 35: val_loss improved from 0.23830 to 0.23763, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 35: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2250 - mae: 0.3093 - val_loss: 0.2376 - val_mae: 0.3337 - learning_rate: 1.2500e-04
# Epoch 36/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2366 - mae: 0.3090
# Epoch 36: val_loss did not improve from 0.23763
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2232 - mae: 0.3082 - val_loss: 0.2387 - val_mae: 0.3334 - learning_rate: 1.2500e-04
# Epoch 37/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2176 - mae: 0.3069
# Epoch 37: val_loss did not improve from 0.23763
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2236 - mae: 0.3085 - val_loss: 0.2382 - val_mae: 0.3326 - learning_rate: 1.2500e-04
# Epoch 38/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2206 - mae: 0.3099
# Epoch 38: val_loss improved from 0.23763 to 0.23725, saving model to /kaggle/working/saved_models/GRU.keras
#
# Epoch 38: finished saving model to /kaggle/working/saved_models/GRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2251 - mae: 0.3093 - val_loss: 0.2372 - val_mae: 0.3334 - learning_rate: 1.2500e-04
# Epoch 39/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2281 - mae: 0.3086
# Epoch 39: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2238 - mae: 0.3084 - val_loss: 0.2388 - val_mae: 0.3327 - learning_rate: 1.2500e-04
# Epoch 40/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2253 - mae: 0.3070
# Epoch 40: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2227 - mae: 0.3075 - val_loss: 0.2383 - val_mae: 0.3345 - learning_rate: 1.2500e-04
# Epoch 41/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2243 - mae: 0.3110
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 41: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2293 - mae: 0.3104 - val_loss: 0.2392 - val_mae: 0.3323 - learning_rate: 1.2500e-04
# Epoch 42/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2244 - mae: 0.3066
# Epoch 42: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2234 - mae: 0.3078 - val_loss: 0.2382 - val_mae: 0.3327 - learning_rate: 6.2500e-05
# Epoch 43/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2243 - mae: 0.3045
# Epoch 43: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2211 - mae: 0.3065 - val_loss: 0.2381 - val_mae: 0.3326 - learning_rate: 6.2500e-05
# Epoch 44/50
# 159/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2115 - mae: 0.3070
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 44: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2221 - mae: 0.3076 - val_loss: 0.2382 - val_mae: 0.3315 - learning_rate: 6.2500e-05
# Epoch 45/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2112 - mae: 0.3048
# Epoch 45: val_loss did not improve from 0.23725
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2219 - mae: 0.3069 - val_loss: 0.2377 - val_mae: 0.3324 - learning_rate: 3.1250e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 38.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
#
# ========================================
# Training CNNGRU
# ========================================
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 18 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5832 - mae: 0.4950
# Epoch 1: val_loss improved from None to 0.38875, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 1: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.4476 - mae: 0.4298 - val_loss: 0.3887 - val_mae: 0.4578 - learning_rate: 0.0010
# Epoch 2/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3233 - mae: 0.3691
# Epoch 2: val_loss improved from 0.38875 to 0.30916, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 2: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.3194 - mae: 0.3646 - val_loss: 0.3092 - val_mae: 0.3903 - learning_rate: 0.0010
# Epoch 3/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3106 - mae: 0.3553
# Epoch 3: val_loss improved from 0.30916 to 0.29036, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 3: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2990 - mae: 0.3515 - val_loss: 0.2904 - val_mae: 0.3660 - learning_rate: 0.0010
# Epoch 4/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3190 - mae: 0.3607
# Epoch 4: val_loss improved from 0.29036 to 0.28539, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 4: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.3017 - mae: 0.3522 - val_loss: 0.2854 - val_mae: 0.3635 - learning_rate: 0.0010
# Epoch 5/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2994 - mae: 0.3446
# Epoch 5: val_loss improved from 0.28539 to 0.27711, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 5: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2832 - mae: 0.3422 - val_loss: 0.2771 - val_mae: 0.3615 - learning_rate: 0.0010
# Epoch 6/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2890 - mae: 0.3425
# Epoch 6: val_loss improved from 0.27711 to 0.26855, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 6: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2788 - mae: 0.3386 - val_loss: 0.2686 - val_mae: 0.3620 - learning_rate: 0.0010
# Epoch 7/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2704 - mae: 0.3364
# Epoch 7: val_loss improved from 0.26855 to 0.26704, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 7: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2747 - mae: 0.3359 - val_loss: 0.2670 - val_mae: 0.3541 - learning_rate: 0.0010
# Epoch 8/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2692 - mae: 0.3329
# Epoch 8: val_loss did not improve from 0.26704
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2672 - mae: 0.3321 - val_loss: 0.2681 - val_mae: 0.3605 - learning_rate: 0.0010
# Epoch 9/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2723 - mae: 0.3373
# Epoch 9: val_loss improved from 0.26704 to 0.25893, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 9: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2685 - mae: 0.3322 - val_loss: 0.2589 - val_mae: 0.3561 - learning_rate: 0.0010
# Epoch 10/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2504 - mae: 0.3255
# Epoch 10: val_loss improved from 0.25893 to 0.25149, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 10: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2569 - mae: 0.3267 - val_loss: 0.2515 - val_mae: 0.3422 - learning_rate: 0.0010
# Epoch 11/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2560 - mae: 0.3253
# Epoch 11: val_loss did not improve from 0.25149
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2574 - mae: 0.3254 - val_loss: 0.2639 - val_mae: 0.3496 - learning_rate: 0.0010
# Epoch 12/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2518 - mae: 0.3224
# Epoch 12: val_loss did not improve from 0.25149
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2533 - mae: 0.3234 - val_loss: 0.2599 - val_mae: 0.3522 - learning_rate: 0.0010
# Epoch 13/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2369 - mae: 0.3205
# Epoch 13: val_loss improved from 0.25149 to 0.24764, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 13: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2507 - mae: 0.3219 - val_loss: 0.2476 - val_mae: 0.3398 - learning_rate: 0.0010
# Epoch 14/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2472 - mae: 0.3218
# Epoch 14: val_loss did not improve from 0.24764
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2477 - mae: 0.3209 - val_loss: 0.2543 - val_mae: 0.3486 - learning_rate: 0.0010
# Epoch 15/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2435 - mae: 0.3196
# Epoch 15: val_loss did not improve from 0.24764
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2442 - mae: 0.3193 - val_loss: 0.2554 - val_mae: 0.3497 - learning_rate: 0.0010
# Epoch 16/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2316 - mae: 0.3176
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_loss did not improve from 0.24764
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2416 - mae: 0.3174 - val_loss: 0.2522 - val_mae: 0.3476 - learning_rate: 0.0010
# Epoch 17/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2322 - mae: 0.3167
# Epoch 17: val_loss improved from 0.24764 to 0.24054, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 17: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2318 - mae: 0.3131 - val_loss: 0.2405 - val_mae: 0.3312 - learning_rate: 5.0000e-04
# Epoch 18/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2263 - mae: 0.3100
# Epoch 18: val_loss did not improve from 0.24054
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2312 - mae: 0.3116 - val_loss: 0.2407 - val_mae: 0.3347 - learning_rate: 5.0000e-04
# Epoch 19/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2474 - mae: 0.3139
# Epoch 19: val_loss did not improve from 0.24054
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2325 - mae: 0.3121 - val_loss: 0.2444 - val_mae: 0.3387 - learning_rate: 5.0000e-04
# Epoch 20/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2173 - mae: 0.3082
# Epoch 20: val_loss improved from 0.24054 to 0.23775, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 20: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2258 - mae: 0.3087 - val_loss: 0.2378 - val_mae: 0.3353 - learning_rate: 5.0000e-04
# Epoch 21/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2168 - mae: 0.3076
# Epoch 21: val_loss did not improve from 0.23775
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2240 - mae: 0.3101 - val_loss: 0.2399 - val_mae: 0.3367 - learning_rate: 5.0000e-04
# Epoch 22/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2204 - mae: 0.3089
# Epoch 22: val_loss did not improve from 0.23775
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2164 - mae: 0.3083 - val_loss: 0.2418 - val_mae: 0.3317 - learning_rate: 5.0000e-04
# Epoch 23/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2113 - mae: 0.3092
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 23: val_loss did not improve from 0.23775
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2163 - mae: 0.3092 - val_loss: 0.2386 - val_mae: 0.3342 - learning_rate: 5.0000e-04
# Epoch 24/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2174 - mae: 0.3057
# Epoch 24: val_loss improved from 0.23775 to 0.23421, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 24: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2107 - mae: 0.3044 - val_loss: 0.2342 - val_mae: 0.3319 - learning_rate: 2.5000e-04
# Epoch 25/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2047 - mae: 0.3035
# Epoch 25: val_loss did not improve from 0.23421
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.2081 - mae: 0.3041 - val_loss: 0.2353 - val_mae: 0.3283 - learning_rate: 2.5000e-04
# Epoch 26/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1944 - mae: 0.3021
# Epoch 26: val_loss improved from 0.23421 to 0.23248, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 26: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.2062 - mae: 0.3031 - val_loss: 0.2325 - val_mae: 0.3285 - learning_rate: 2.5000e-04
# Epoch 27/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1970 - mae: 0.3012
# Epoch 27: val_loss did not improve from 0.23248
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2009 - mae: 0.3011 - val_loss: 0.2336 - val_mae: 0.3268 - learning_rate: 2.5000e-04
# Epoch 28/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2016 - mae: 0.3012
# Epoch 28: val_loss did not improve from 0.23248
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.2035 - mae: 0.3017 - val_loss: 0.2360 - val_mae: 0.3309 - learning_rate: 2.5000e-04
# Epoch 29/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1950 - mae: 0.3011
# Epoch 29: val_loss improved from 0.23248 to 0.23210, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 29: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1997 - mae: 0.3012 - val_loss: 0.2321 - val_mae: 0.3280 - learning_rate: 2.5000e-04
# Epoch 30/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1973 - mae: 0.2978
# Epoch 30: val_loss did not improve from 0.23210
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1970 - mae: 0.3002 - val_loss: 0.2330 - val_mae: 0.3296 - learning_rate: 2.5000e-04
# Epoch 31/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2007 - mae: 0.2997
# Epoch 31: val_loss improved from 0.23210 to 0.23145, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 31: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.1975 - mae: 0.2999 - val_loss: 0.2315 - val_mae: 0.3323 - learning_rate: 2.5000e-04
# Epoch 32/50
# 160/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1965 - mae: 0.2995
# Epoch 32: val_loss did not improve from 0.23145
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1955 - mae: 0.2992 - val_loss: 0.2341 - val_mae: 0.3315 - learning_rate: 2.5000e-04
# Epoch 33/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2061 - mae: 0.2999
# Epoch 33: val_loss improved from 0.23145 to 0.23010, saving model to /kaggle/working/saved_models/CNNGRU.keras
#
# Epoch 33: finished saving model to /kaggle/working/saved_models/CNNGRU.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.1967 - mae: 0.2994 - val_loss: 0.2301 - val_mae: 0.3268 - learning_rate: 2.5000e-04
# Epoch 34/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2041 - mae: 0.2994
# Epoch 34: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1973 - mae: 0.2985 - val_loss: 0.2308 - val_mae: 0.3320 - learning_rate: 2.5000e-04
# Epoch 35/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1944 - mae: 0.2979
# Epoch 35: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1945 - mae: 0.2984 - val_loss: 0.2324 - val_mae: 0.3274 - learning_rate: 2.5000e-04
# Epoch 36/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1967 - mae: 0.2983
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 36: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1930 - mae: 0.2984 - val_loss: 0.2330 - val_mae: 0.3285 - learning_rate: 2.5000e-04
# Epoch 37/50
# 161/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1936 - mae: 0.2962
# Epoch 37: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1915 - mae: 0.2964 - val_loss: 0.2310 - val_mae: 0.3272 - learning_rate: 1.2500e-04
# Epoch 38/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1900 - mae: 0.2945
# Epoch 38: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1903 - mae: 0.2959 - val_loss: 0.2314 - val_mae: 0.3309 - learning_rate: 1.2500e-04
# Epoch 39/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1948 - mae: 0.2966
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 39: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1897 - mae: 0.2964 - val_loss: 0.2315 - val_mae: 0.3284 - learning_rate: 1.2500e-04
# Epoch 40/50
# 162/163 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1906 - mae: 0.2953
# Epoch 40: val_loss did not improve from 0.23010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1850 - mae: 0.2944 - val_loss: 0.2306 - val_mae: 0.3266 - learning_rate: 6.2500e-05
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 33.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
#
# === Model Comparison ===
#              MSE       MAE      RMSE
# GRU     0.001012  0.020420  0.031813
# LSTM    0.001058  0.020700  0.032531
# CNNGRU  0.001066  0.020862  0.032646
# Metrics saved to /kaggle/working/saved_models/metrics.csv

# %%
sample_companies = list(test_indices.keys())
random_companies = np.random.choice(sample_companies, size=3, replace=False)

for company in random_companies:
    plot(histories['CNNGRU'], model_configs['CNNGRU'], X_test, y_test, all_X_test, test_indices, scaler, features, sample_company=company)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
